# %%
# Initial imports
import os
import pandas as pd
from dotenv import load_dotenv
import nltk as nltk
import requests
from pathlib import Path
import datetime as dt

nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %matplotlib inline
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
# Read your api key environment variable
load_dotenv()
api_key = os.getenv("NEWS_API_KEY")
print(api_key)
# Out:
# 1ee42792279e4bb38c96b682f9029b47

# %%
# Create a newsapi client
from newsapi import NewsApiClient
newsapi = NewsApiClient(api_key)

# %%
search_term= input("What Search Term?")
# Out:
# What Search Term? Ethereum

# %%
# Fetch the news articles
eth_headlines = newsapi.get_everything(
    search_term,
    language="en",
    page_size=100,
    sort_by="relevancy"
)
eth_headlines
# Out:
# {'status': 'ok',
#  'totalResults': 4663,
#  'articles': [{'source': {'id': 'engadget', 'name': 'Engadget'},
#    'author': 'Jon Fingas',
#    'title': "Here's what NFTs look like on Instagram",
#    'description': "Meta has revealed more of how NFTs will work on Instagram. In the US-based test, you can show what you've bought or created for free by connecting your Instagram account to a compatible digital wallet and posting for the world to see. If you like, the social …",
#    'url': 'https://www.engadget.com/instagram-nft-details-131020868.html',
#    'urlToImage': 'https://s.yimg.com/os/creatr-uploaded-images/2022-05/2546c160-d05e-11ec-b75e-e45eaa8c5b2b',
#    'publishedAt': '2022-05-10T13:10:20Z',
#    'content': "Meta has revealed more of how NFTs will work on Instagram. In the US-based test, you can show what you've bought or created for free by connecting your Instagram account to a compatible digital walle… [+1223 chars]"},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'Kyle Barr',
#    'title': 'GameStop Dunks Its Head Into the Crypto Kiddie Pool',
#    'description': 'GameStop has officially thrown itself headlong into the web3 vipers nest with a new app release, though it’s hard to say whether its proposed population of gamers and game developers will take up the company on its belated, head-first jump into the crypto sph…',
#    'url': 'https://gizmodo.com/gamestop-crypto-nft-wallet-blockchain-1848965386',
#    'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/cd4c128b4182d7b2fba8152d7bb35733.jpg',
#    'publishedAt': '2022-05-23T21:35:00Z',
#    'content': 'GameStop has officially thrown itself headlong into the web3 vipers nest with a new app release, though its hard to say whether its proposed population of gamers and game developers will take up the … [+3255 chars]'},
#   {'source': {'id': None, 'name': 'CNET'},
#    'author': 'Daniel Van Boom',
#    'title': 'How Bored Ape Yacht Club Broke Ethereum - CNET',
#    'description': 'Transactions stalled for hours, and people paid thousands in fees whether their purchase succeeded or not.',
#    'url': 'https://www.cnet.com/personal-finance/crypto/how-bored-ape-yacht-club-broke-ethereum/',
#    'urlToImage': 'https://www.cnet.com/a/img/resize/ec8610207cf749f84654799866cb67699ac91a6d/2022/05/01/9c9ba1e1-519b-4e61-a12a-f3faa5d2f1a0/otherside-launch-image-rc1.jpg?auto=webp&fit=crop&height=630&width=1200',
#    'publishedAt': '2022-05-04T02:32:00Z',
#    'content': 'When Bored Ape Yacht Club creators Yuga Labs announced its Otherside NFT collection would launch on April 30, it was predicted by many to be the biggest NFT launch ever. Otherside is an upcoming Bore… [+6669 chars]'},
#   {'source': {'id': None, 'name': 'CNET'},
#    'author': 'Sarah Lord',
#    'title': 'GameStop Launching Digital Wallet for Cryptocurrencies, NFTs - CNET',
#    'description': "The self-custodial Ethereum wallet will have its own Google Chrome extension and can be used to complete transactions on the company's upcoming NFT marketplace.",
#    'url': 'https://www.cnet.com/tech/services-and-software/gamestop-launching-digital-wallet-for-cryptocurrencies-nfts/',
#    'urlToImage': 'https://www.cnet.com/a/img/resize/00e1b8fca281f501a409d88e2eda84a4231959db/2022/02/03/f408f29c-7a96-4e3f-b04d-53f792972f8c/gettyimages-1235868944.jpg?auto=webp&fit=crop&height=630&width=1200',
#    'publishedAt': '2022-05-23T14:06:00Z',
#    'content': 'GameStop is going all-in on crypto. The video game retailer launched\xa0its own self-custodial Ethereum digital wallet, it said Monday. The wallet will be accessible through a Google Chrome extension an… [+1491 chars]'},
#   {'source': {'id': 'engadget', 'name': 'Engadget'},
#    'author': 'Kris Holt',
#    'title': 'New York passes a bill to limit bitcoin mining',
#    'description': "New York lawmakers have passed a bill\r\n that would temporarily ban new bitcoin\r\n mining operations. Early on Friday, state senators voted 36-27 to pass the legislation. It's now bound for the desk of Governor Kathy Hochul, who will sign it into law or veto th…",
#    'url': 'https://www.engadget.com/new-york-cryptocurrency-bill-bitcoin-mining-climate-change-161126292.html',
#    'urlToImage': 'https://s.yimg.com/os/creatr-uploaded-images/2021-05/a8217250-bdfa-11eb-bfc4-2663225cea83',
#    'publishedAt': '2022-06-03T16:11:26Z',
#    'content': "New York lawmakers have passed a bill\r\n that would temporarily ban new bitcoin\r\n mining operations. Early on Friday, state senators voted 36-27 to pass the legislation. It's now bound for the desk of… [+2036 chars]"},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': "'Pay more attention' Ethereum co-founder says of crypto crash - Reuters",
#    'description': "Ethereum's co-founder Gavin Wood said cryptocurrency investors need to be more aware of what is backing their holdings after a market rout which wiped more than $800 billion off their value.",
#    'url': 'https://www.reuters.com/markets/us/pay-more-attention-ethereum-co-founder-says-crypto-crash-2022-05-25/',
#    'urlToImage': 'https://www.reuters.com/resizer/XsA-mJuk-UfiaqX_lbwtVZ8Egp4=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/TK5SKXCQMNPBFOQOZZTJB55GHQ.jpg',
#    'publishedAt': '2022-05-25T09:33:00Z',
#    'content': "DAVOS, Switzerland, May 25 (Reuters) - Ethereum's co-founder Gavin Wood said cryptocurrency investors need to be more aware of what is backing their holdings after a market rout which wiped more than… [+1744 chars]"},
#   {'source': {'id': 'time', 'name': 'Time'},
#    'author': None,
#    'title': 'Ethereum and Bitcoin Prices Are Tanking. Here’s Why One Expert Thinks Bitcoin Could Drop Even Lower - NextAdvisor',
#    'description': '<ol><li>Ethereum and Bitcoin Prices Are Tanking. Here’s Why One Expert Thinks Bitcoin Could Drop Even Lower\xa0\xa0NextAdvisor\r\n</li><li>Does the cryptocurrency crash pose a threat to the financial system?\xa0\xa0Financial Post\r\n</li><li>Going ‘To Zero’—Panic Is Sweeping…',
#    'url': 'https://time.com/nextadvisor/investing/cryptocurrency/cryptocurrency-btc-eth-price-falling/',
#    'urlToImage': 'https://time.com/nextadvisor/wp-content/uploads/2022/05/daily-crypto-update-4-9-1000x630.jpg',
#    'publishedAt': '2022-05-09T16:44:18Z',
#    'content': 'Editorial IndependenceWe want to help you make more informed decisions. Some links on this page clearly marked may take you to a partner website and may result in us earning a referral commission. Fo… [+6022 chars]'},
#   {'source': {'id': None, 'name': 'Slashdot.org'},
#    'author': 'EditorDavid',
#    'title': 'Cryptocurrency Markets Drop $200B, Bitcoin Down 50% Since November',
#    'description': '40 days ago Bitcoin sold for $47,454. It\'s price now is $34,007 — a drop of 28%. \nAbout a third of that drop happened this week, as "Bitcoin, ethereum and other major cryptocurrencies have fallen sharply," Forbes reports, "wiping around $200 billion from the …',
#    'url': 'https://news.slashdot.org/story/22/05/09/0026233/cryptocurrency-markets-drop-200b-bitcoin-down-50-since-november',
#    'urlToImage': 'https://a.fsdn.com/sd/topics/bitcoin_64.png',
#    'publishedAt': '2022-05-09T01:34:00Z',
#    'content': '40 days ago Bitcoin sold for $47,454. It\'s price now is $34,007 — a drop of 28%.About a third of that drop happened this week, as "Bitcoin, ethereum and other major cryptocurrencies have fallen sharp… [+975 chars]'},
#   {'source': {'id': None, 'name': 'Slashdot.org'},
#    'author': 'EditorDavid',
#    'title': "Report: 'Nvidia's LHR Limiter Has Fallen, But Gamers Shouldn't Worry'",
#    'description': 'Slashdot reader Hmmmmmm shared this report from Hot Hardware:\n\nWhen Nvidia launched its Ampere Lite Hash Rate (LHR) graphics card with the feared Ethereum anti-mining limiter, the world knew it was only a matter of time before someone or a team cracked it. Ni…',
#    'url': 'https://tech.slashdot.org/story/22/05/15/190252/report-nvidias-lhr-limiter-has-fallen-but-gamers-shouldnt-worry',
#    'urlToImage': 'https://a.fsdn.com/sd/topics/graphics_64.png',
#    'publishedAt': '2022-05-15T19:39:00Z',
#    'content': 'When Nvidia launched its Ampere Lite Hash Rate (LHR) graphics card with the feared Ethereum anti-mining limiter, the world knew it was only a matter of time before someone or a team cracked it. NiceH… [+1230 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Bitcoin last up 5.7% at $39862.84 - Reuters.com',
#    'description': 'Bitcoin rose 5.7% to $39,862.84, on Wednesday, adding $2,102.94 to its previous close.',
#    'url': 'https://www.reuters.com/business/bitcoin-last-up-57-3986284-2022-05-04/',
#    'urlToImage': 'https://www.reuters.com/resizer/BWWUiBev3PUU7DomJJXE2-Iqz30=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/OZ6CVP422VIJ5A6UACI72VHUSY.jpg',
#    'publishedAt': '2022-05-04T20:16:00Z',
#    'content': "May 4 (Reuters) - Bitcoin rose 5.7% to $39,862.84, on Wednesday, adding $2,102.94 to its previous close.\r\nBitcoin, the world's biggest and best-known cryptocurrency, is up 20.9% from the year's low o… [+337 chars]"},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Bitcoin falls 7.2% to $28758 - Reuters.com',
#    'description': 'Bitcoin fell 7.23% to $28,758.29 at 22:05 GMT on Wednesday, losing $2,241.68 from its previous close.',
#    'url': 'https://www.reuters.com/business/bitcoin-falls-72-28758-2022-05-11/',
#    'urlToImage': 'https://www.reuters.com/resizer/lEay-or8c9TPjZOEmIjrJf3ylQk=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/3RKTTS2CRVM2BEEDCB2ZIPV3L4.jpg',
#    'publishedAt': '2022-05-11T22:18:00Z',
#    'content': "May 11 (Reuters) - Bitcoin fell 7.23% to $28,758.29 at 22:05 GMT on Wednesday, losing $2,241.68 from its previous close.\r\nBitcoin, the world's biggest and best-known cryptocurrency, is down 40.4% fro… [+361 chars]"},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Bitcoin falls 7.8% to $31333 - Reuters',
#    'description': 'Bitcoin dropped 7.81% to $31,333.41 at 20:03 GMT on Monday, losing $2,655.98 from its previous close.',
#    'url': 'https://www.reuters.com/business/bitcoin-falls-78-31333-2022-05-09/',
#    'urlToImage': 'https://www.reuters.com/resizer/BWWUiBev3PUU7DomJJXE2-Iqz30=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/OZ6CVP422VIJ5A6UACI72VHUSY.jpg',
#    'publishedAt': '2022-05-09T20:11:00Z',
#    'content': "May 9 (Reuters) - Bitcoin dropped 7.81% to $31,333.41 at 20:03 GMT on Monday, losing $2,655.98 from its previous close.\r\nBitcoin, the world's biggest and best-known cryptocurrency, is down 35% from t… [+351 chars]"},
#   {'source': {'id': 'ars-technica', 'name': 'Ars Technica'},
#    'author': 'Andrew Cunningham',
#    'title': 'NiceHash software unlocks full crypto-mining performance for most Nvidia GPUs',
#    'description': "But the workaround still can't defeat the newest version of Nvidia's LHR tech.",
#    'url': 'https://arstechnica.com/gadgets/2022/05/nicehash-software-unlocks-full-cryptomining-performance-for-most-nvidia-gpus/',
#    'urlToImage': 'https://cdn.arstechnica.net/wp-content/uploads/2018/03/30770561533_a4ea9f1dd9_o-760x380.jpg',
#    'publishedAt': '2022-05-09T16:52:01Z',
#    'content': '9 with 8 posters participating\r\nNvidia began releasing LHR (or Lite Hash Rate) graphics cards last year\xa0to slow down their cryptocurrency mining performance and make them less appealing to non-gamers… [+2182 chars]'},
#   {'source': {'id': None, 'name': 'Bitcoin.com'},
#    'author': None,
#    'title': 'Bitcoin, Ethereum Technical Analysis: BTC Slips to 10-Month Low, Below $33000 – Market Updates Bitcoin News - Bitcoin News',
#    'description': '<ol><li>Bitcoin, Ethereum Technical Analysis: BTC Slips to 10-Month Low, Below $33000 – Market Updates Bitcoin News\xa0\xa0Bitcoin News\r\n</li><li>Bitcoin drops 50% from peak, near lowest levels in last one year\xa0\xa0Economic Times\r\n</li><li>Crypto Crash: Why is cryptoc…',
#    'url': 'https://news.bitcoin.com/bitcoin-ethereum-technical-analysis-btc-slips-to-10-month-low-below-33000/',
#    'urlToImage': 'https://static.news.bitcoin.com/wp-content/uploads/2022/05/shutterstock_1978798856-1.jpg',
#    'publishedAt': '2022-05-09T13:45:30Z',
#    'content': 'BTC fell to its lowest level since last July, as prices dropped below $33,000 to start the week. The selloff in cryptocurrency started last week, following the Fed’s decision to hike interest rates b… [+2651 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'mfox@businessinsider.com (Matthew Fox)',
#    'title': 'Weekly NFT sales plunge 50% to $255 million amid crypto bear market. These were the 5 best-selling digital collections.',
#    'description': 'Total NFT sales volume hit $29 billion over the past year as artists, investors, and entrepreneurs descend upon the nascent Web3 space.',
#    'url': 'https://markets.businessinsider.com/news/currencies/bored-ape-yacht-club-reclaims-top-spot-weekly-nft-sales-2022-5',
#    'urlToImage': 'https://i.insider.com/628508651aa29100196a381f?width=1200&format=jpeg',
#    'publishedAt': '2022-05-18T15:53:28Z',
#    'content': 'The cryptocurrency boom over the past few years has helped propel a newer market to record heights: digital collectibles known as NFTs.\xa0\r\nThe craze has pushed total NFT sales volume to $29 billion ov… [+2866 chars]'},
#   {'source': {'id': None, 'name': 'Entrepreneur'},
#    'author': 'John Monarch',
#    'title': 'Can Blockchain Help Fix Broken Supply Chains in 2022?',
#    'description': 'Blockchain in Supply Chain was a hot topic - then fell very quiet. Where is it today?',
#    'url': 'https://www.entrepreneur.com/article/426351',
#    'urlToImage': 'https://assets.entrepreneur.com/content/3x2/2000/1653325433-GettyImages-1194691729.jpg',
#    'publishedAt': '2022-06-03T14:00:00Z',
#    'content': 'We first heard about the potential of blockchain in supply chains several years ago, and almost immediately were thrust into a cycle of hype and hope of what they could do for us, followed by a "trou… [+4785 chars]'},
#   {'source': {'id': 'bbc-news', 'name': 'BBC News'},
#    'author': 'https://www.facebook.com/bbcnews',
#    'title': 'Bitcoin value drops by 50% since November peak',
#    'description': 'The slide in the value of cryptocurrencies comes as stock markets around the world have also fallen.',
#    'url': 'https://www.bbc.co.uk/news/business-61375152',
#    'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/8362/production/_124643633_gettyimages-1384896168.jpg',
#    'publishedAt': '2022-05-09T03:04:37Z',
#    'content': "Image source, Getty Images\r\nThe value of Bitcoin continued to fall over the weekend as it dropped below $34,000 (£27,630), according to the Coinbase cryptocurrency exchange.\r\nThe world's largest cryp… [+2164 chars]"},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'bevans@insider.com (Brian Evans)',
#    'title': 'Solana tumbles as its blockchain network suffers 2nd outage in a month',
#    'description': 'Solana suffered similar turbulence on May 1, when its network remained down for roughly seven hours.',
#    'url': 'https://markets.businessinsider.com/news/currencies/solana-price-sol-tumbles-blockchain-network-suffers-2nd-outage-month-2022-6',
#    'urlToImage': 'https://i.insider.com/6297c14ce319620018a80e29?width=1200&format=jpeg',
#    'publishedAt': '2022-06-01T19:58:36Z',
#    'content': 'Solana, the third largest cryptocurrency by market capitalization, fell 10% Wednesday following reports of its blockchain network suffering another outage.\xa0\r\nThe blockchain had not produced new block… [+566 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'mfox@businessinsider.com (Matthew Fox)',
#    'title': 'Weekly NFT sales drop 23% to $191 million amid crypto bear market. These were the 5 best-selling digital collections.',
#    'description': 'Total NFT sales volume hit $29 billion over the past year as artists, investors, and entrepreneurs descend upon the nascent Web3 space.',
#    'url': 'https://markets.businessinsider.com/news/currencies/meebits-rise-top-spot-weekly-nft-sales-crypto-bored-apes-2022-5',
#    'urlToImage': 'https://i.insider.com/627281def6bd4b0019cb550c?width=1200&format=jpeg',
#    'publishedAt': '2022-05-25T14:55:04Z',
#    'content': 'The cryptocurrency boom over the past few years has helped propel a newer market to record heights: digital collectibles known as NFTs.\xa0\r\nThe craze has pushed total NFT sales volume to $29 billion ov… [+2830 chars]'},
#   {'source': {'id': 'ars-technica', 'name': 'Ars Technica'},
#    'author': 'Jon Brodkin',
#    'title': 'NY passes US-first moratorium on reviving fossil fuel plants to mine crypto',
#    'description': 'If signed by gov., bill would halt permits while state studies environmental impact.',
#    'url': 'https://arstechnica.com/tech-policy/2022/06/ny-passes-us-first-moratorium-on-reviving-fossil-fuel-plants-to-mine-crypto/',
#    'urlToImage': 'https://cdn.arstechnica.net/wp-content/uploads/2022/06/getty-bitcoin-760x380.jpg',
#    'publishedAt': '2022-06-03T20:26:26Z',
#    'content': "6 with 6 posters participating\r\nNew York's state legislature approved a bill that would prevent fossil fuel power plants from being revived to power cryptocurrency mining operations. If signed by Gov… [+3200 chars]"},
#   {'source': {'id': 'wired', 'name': 'Wired'},
#    'author': 'Steven Levy',
#    'title': 'Meta’s New COO Is Nothing Like Sheryl Sandberg',
#    'description': 'Plus: The early days of Facebook, charitable donations, and a disconcerting playlist.',
#    'url': 'https://www.wired.com/story/plaintext-meta-new-coo-sheryl-sandberg/',
#    'urlToImage': 'https://media.wired.com/photos/62995c649fa3280504562879/191:100/w_1280,c_limit/Javier-Olivan-Meta-COO-Business-Plain-Background.jpg',
#    'publishedAt': '2022-06-03T13:00:00Z',
#    'content': 'Hey, folks. Were deadlocked on gun safety, the Ukraine war still grinds on, and a gallon of gas is approaching the price of an Ethereum gas fee. At least we dont have to deal with Johnny Depp for ano… [+4167 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'insider@insider.com (Aprilynne Alter)',
#    'title': '50 cryptocurrency and NFT terms you need to know',
#    'description': 'Web3 Youtuber Aprilynne Alters shares a list of crypto and NFT words and definitions so that even the most tech-averse folks can understand.',
#    'url': 'https://www.businessinsider.com/bitcoin-nft-crypto-web-3-terms-you-should-know-2022-5',
#    'urlToImage': 'https://i.insider.com/6287a24e8641770019bd71d6?width=1200&format=jpeg',
#    'publishedAt': '2022-05-20T14:20:14Z',
#    'content': "If you're inexperienced with NFTS, some terms may be confusing.\r\nI'm a full-time YouTuber focused on demystifying all things Web3, but when I was first learning about the Web3 space, it seemed like p… [+8587 chars]"},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Gucci jumps on the crypto bandwagon with U.S. project - Reuters.com',
#    'description': "Gucci's high-end handbags and other luxury products can now be bought using cryptocurrencies, including bitcoin, in some U.S. stores, the Italian company said, as digital currencies move to broader acceptance.",
#    'url': 'https://www.reuters.com/business/retail-consumer/gucci-jumps-crypto-bandwagon-with-us-project-2022-05-05/',
#    'urlToImage': 'https://www.reuters.com/resizer/aLPEIt4kysCMpwdBeNLdWl6_YxU=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/353HRRTJVVKDLIMZK5Y3V2JP3I.jpg',
#    'publishedAt': '2022-05-05T08:26:00Z',
#    'content': "May 5 (Reuters) - Gucci's high-end handbags and other luxury products can now be bought using cryptocurrencies, including bitcoin, in some U.S. stores, the Italian company said, as digital currencies… [+1161 chars]"},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Corin Faife',
#    'title': 'Stablecoins are struggling to survive the crypto crash',
#    'description': 'After the Terra stablecoin broke its dollar peg and dropped to less than 30 cents, investors have been watching closely for repercussions across cryptocurrency markets.',
#    'url': 'https://www.theverge.com/2022/5/12/23069232/terra-luna-collapse-stablecoins-crypto-crash-bitcoin',
#    'urlToImage': 'https://cdn.vox-cdn.com/thumbor/rUaR5RqYmvfihRfA_BzIMNOzcio=/0x146:2040x1214/fit-in/1200x630/cdn.vox-cdn.com/uploads/chorus_asset/file/10576389/acastro_180402_2428_001.jpg',
#    'publishedAt': '2022-05-12T20:56:14Z',
#    'content': 'Once pegged to the dollar, Terras UST coin is now trading at 40 cents\r\nIllustration by Alex Castro\r\nIts been a crushing few days for the Terra project, in a week that has been unforgiving for cryptoc… [+4159 chars]'},
#   {'source': {'id': None, 'name': 'CNET'},
#    'author': 'Julian Dossett',
#    'title': "After Luna Collapse, Terra Looks to New Blockchain. This Week's Top Bitcoin and Crypto News - CNET",
#    'description': 'All the bitcoin, cryptocurrency and NFT news for the week ending May 20.',
#    'url': 'https://www.cnet.com/personal-finance/crypto/after-luna-collapse-terra-looks-to-new-blockchain-this-weeks-top-bitcoin-and-crypto-news/',
#    'urlToImage': 'https://www.cnet.com/a/img/resize/941676ec40a5f484a5a3421c0fab4fc66d83adf2/2022/04/23/ddcb4d2b-32be-43f0-b48f-f6d31e44bec9/crypto-story-1.png?auto=webp&fit=crop&height=630&width=1200',
#    'publishedAt': '2022-05-21T11:30:06Z',
#    'content': "After two linked cryptocurrencies collapsed and became almost worthless, a plan emerged to create a new blockchain for the luna cryptocurrency. Seth Green's NFTs were stolen in a phishing scam. Nike … [+3932 chars]"},
#   {'source': {'id': None, 'name': 'CNET'},
#    'author': 'Daniel Van Boom',
#    'title': "Terra's Plan to Revive Luna After Historic Crypto Crash - CNET",
#    'description': 'Terralabs founder Kwon Do wants to create a new blockchain and distribute hundreds of millions of new luna tokens to burned investors.',
#    'url': 'https://www.cnet.com/personal-finance/crypto/terras-plan-to-revive-luna-after-historic-crypto-crash/',
#    'urlToImage': 'https://www.cnet.com/a/img/resize/f90165eae4cb2cb61453618e4f28cc17804b388d/2022/05/17/0d3b68a5-361e-464c-ae13-1c3c9b182c63/gettyimages-1240635265.jpg?auto=webp&fit=crop&height=630&width=1200',
#    'publishedAt': '2022-05-17T03:38:00Z',
#    'content': 'May has been a tough month for all cryptocurrencies, but especially for luna. While bitcoin and ether are down 25% and 30% respectively, the luna token cratered from $81 a month ago to a fraction of … [+3634 chars]'},
#   {'source': {'id': None, 'name': 'The Guardian'},
#    'author': 'Alex Hern UK technology editor',
#    'title': 'TerraUSD ‘stablecoin’ delisted from crypto exchanges',
#    'description': '‘Algorithmic stablecoin’, whose collapse triggered multibillion-dollar selloff, turns off blockchainTerraUSD, the “algorithmic stablecoin” whose collapse prompted a multibillion-dollar selloff across crypto markets, has turned off its blockchain and been deli…',
#    'url': 'https://amp.theguardian.com/technology/2022/may/13/terrausd-stablecoin-crypto-exchanges',
#    'urlToImage': 'https://i.guim.co.uk/img/media/1b178fdbbfa0db5fde7959b86ba45232c3a3baf5/0_384_5760_3456/master/5760.jpg?width=1200&height=630&quality=85&auto=format&fit=crop&overlay-align=bottom%2Cleft&overlay-width=100p&overlay-base64=L2ltZy9zdGF0aWMvb3ZlcmxheXMvdGctZGVmYXVsdC5wbmc&enable=upscale&s=6860d93061e97f54bac1b4a68eb647f8',
#    'publishedAt': '2022-05-13T11:09:26Z',
#    'content': 'TerraUSD, the algorithmic stablecoin whose collapse prompted a multibillion-dollar selloff across crypto markets, has turned off its blockchain and been delisted from major exchanges, in effect shutt… [+3641 chars]'},
#   {'source': {'id': None, 'name': 'Bearblog.dev'},
#    'author': None,
#    'title': "You shouldn't invest in the crypto currency?",
#    'description': 'Disclaimer - I have invested 1% of my savings into stable cryptocurrencies such as Bitcoin and Ethereum etc.\nLet’s talk about slot games first. Most of them are',
#    'url': 'https://rohitgupta.bearblog.dev/why-you-shouldnt-invest-in-the-crypto-currency/',
#    'urlToImage': None,
#    'publishedAt': '2022-05-10T19:16:40Z',
#    'content': 'Disclaimer - I have invested 1% of my savings into stable cryptocurrencies such as Bitcoin and Ethereum etc.\r\nLets talk about slot games first. Most of them are designed in such a way that you will w… [+955 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Bitcoin falls to lowest since January, in line with tumbling stock markets - Reuters',
#    'description': 'Bitcoin fell to its lowest level since January on Monday as slumping equity markets continued to hurt cryptocurrencies, which are currently trading in line with so-called riskier assets like tech stocks.',
#    'url': 'https://www.reuters.com/business/finance/bitcoin-falls-lowest-since-january-line-with-tumbling-stock-markets-2022-05-09/',
#    'urlToImage': 'https://www.reuters.com/resizer/B0qAxA8TjZ596MlWtB1mhDiQ1HM=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/SBR5WIGRUVJBRNZBI6EL6DOKVA.jpg',
#    'publishedAt': '2022-05-09T04:43:00Z',
#    'content': 'HONG KONG, May 9 (Reuters) - Bitcoin fell to its lowest level since January on Monday as slumping equity markets continued to hurt cryptocurrencies, which are currently trading in line with so-called… [+1775 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Crypto lender Babel Finance valued at $2 billion after latest fundraising - Reuters.com',
#    'description': 'Hong Kong-based Babel Finance said on Wednesday it had raised $80 million in a new funding round that valued the cryptocurrency lender and asset manager at $2 billion.',
#    'url': 'https://www.reuters.com/markets/wealth/crypto-lender-babel-finance-valued-2-billion-after-latest-fundraising-2022-05-25/',
#    'urlToImage': 'https://www.reuters.com/resizer/qtFOvHOgY-Bv63LX1PzCLfWs25w=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/SWBLTHOVWJMCXHGWN726BGSKJY.jpg',
#    'publishedAt': '2022-05-25T12:56:00Z',
#    'content': 'May 25 (Reuters) - Hong Kong-based Babel Finance said on Wednesday it had raised $80 million in a new funding round that valued the cryptocurrency lender and asset manager at $2 billion.\r\nInvestors w… [+1648 chars]'},
#   {'source': {'id': 'financial-post', 'name': 'Financial Post'},
#    'author': 'Financial Post Staff',
#    'title': 'Bitcoin, cryptocurrency shed $200 billion in one day - Financial Post',
#    'description': '<ol><li>Bitcoin, cryptocurrency shed $200 billion in one day\xa0\xa0Financial Post\r\n</li><li>$1 Trillion Crypto Meltdown—Huge Crash Wipes Out The Price Of Bitcoin, Ethereum, BNB, XRP, Cardano, Solana, Terra’s Luna And Avalanche\xa0\xa0Forbes\r\n</li><li>Crypto market’s cra…',
#    'url': 'https://financialpost.com/fp-finance/cryptocurrency/what-you-need-to-know-about-the-rout-that-just-wiped-200-billion-off-the-cryptocurrency-market-in-one-day',
#    'urlToImage': 'https://smartcdn.gprod.postmedia.digital/financialpost/wp-content/uploads/2022/05/bitcoin-0512.jpg',
#    'publishedAt': '2022-05-12T12:26:01Z',
#    'content': 'Contagion spreading to stock markets as investors see one more thing to worry about \r\nA massive sell-off has spread like wildfire through the world of cryptocurrencies.Photo by REUTERS/Dado Ruvic/Fil… [+7621 chars]'},
#   {'source': {'id': None, 'name': 'VentureBeat'},
#    'author': 'Dean Takahashi',
#    'title': 'Kongregate and Immutable X launch $40M blockchain game dev fund',
#    'description': 'Kongregate has teamed up with Immutable X for a $40 million fund to give grants to developers who make blockchain games for Kongregate.com.',
#    'url': 'https://venturebeat.com/2022/05/25/kongregate-and-immutable-x-launch-40m-blockchain-game-dev-fund/',
#    'urlToImage': 'https://venturebeat.com/wp-content/uploads/2022/05/kongregate.jpg?w=1200&strip=all',
#    'publishedAt': '2022-05-25T16:00:00Z',
#    'content': 'Did you miss a session from GamesBeat Summit 2022? All sessions are available to stream now. Watch now.\r\nWeb gaming platform Kongregate has teamed up with blockchain game tech company Immutable X for… [+826 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'tmohamed@businessinsider.com (Theron Mohamed)',
#    'title': "George Soros' deputy sounds the recession alarm, slams SPACs, and says crypto is here to stay. Here are her 11 best quotes from a new interview.",
#    'description': 'Dawn Fitzpatrick, the head of Soros Fund Management, called out the Fed for being slow to tackle inflation, and underlined the dangers of FOMO.',
#    'url': 'https://markets.businessinsider.com/news/stocks/george-soros-dawn-fitzpatrick-recession-spac-fed-crypto-bitcoin-ethereum-2022-6',
#    'urlToImage': 'https://i.insider.com/5c0a54cadde86764c431ac96?width=1200&format=jpeg',
#    'publishedAt': '2022-06-01T11:09:39Z',
#    'content': 'George Soros\' deputy warned a \r\nrecession is coming, predicted ethereum would gain ground on bitcoin, and called out the \r\nFederal Reserve for belatedly tackling inflation in a recent episode\xa0of "Blo… [+2920 chars]'},
#   {'source': {'id': 'wired', 'name': 'Wired'},
#    'author': "Meghan O'Gieblyn",
#    'title': 'Can Social Media Be Redeemed?',
#    'description': 'WIRED’s spiritual advice columnist on Jack Dorsey’s remorse for his role in creating a centralized internet and what it signals for the rest of us.',
#    'url': 'https://www.wired.com/story/can-social-media-be-redeemed/',
#    'urlToImage': 'https://media.wired.com/photos/62756b69ada91b8860a6f0d5/191:100/w_1280,c_limit/WI060122_ST_CloudSupport_01.jpg',
#    'publishedAt': '2022-05-11T12:00:00Z',
#    'content': 'I read that Jack Dorsey, a cofounder of Twitter, claims to regret his role in creating the centralized internet. Given what we know about the divisiveness, violence, and misinformation that social me… [+7774 chars]'},
#   {'source': {'id': None, 'name': 'Ctvnews.ca'},
#    'author': None,
#    'title': 'Poilievre personally holds investment in Bitcoin as he promotes crypto to Canadians - CTV News',
#    'description': 'Conservative Party leadership candidate Pierre Poilievre has a personal financial interest in cryptocurrencies that he has promoted during his campaign as a hedge against inflation.',
#    'url': 'https://www.ctvnews.ca/politics/poilievre-personally-holds-investment-in-bitcoin-as-he-promotes-crypto-to-canadians-1.5907615',
#    'urlToImage': 'https://www.ctvnews.ca/content/dam/ctvnews/en/images/2022/5/17/pierre-poilievre-1-5907634-1652823979715.jpg',
#    'publishedAt': '2022-05-17T21:47:00Z',
#    'content': 'Conservative Party leadership candidate Pierre Poilievre has a personal financial interest in cryptocurrencies that he has promoted during his campaign as a hedge against inflation.\r\nThe Ottawa-area … [+4372 chars]'},
#   {'source': {'id': None, 'name': 'Entrepreneur'},
#    'author': 'Entrepreneur en Español',
#    'title': 'AxenCoin, the new Mexican cryptocurrency',
#    'description': 'In addition to serving as an investment instrument, cryptocurrency will make it possible to pay for goods and services in the near future.',
#    'url': 'https://www.entrepreneur.com/article/426714',
#    'urlToImage': 'https://assets.entrepreneur.com/content/3x2/2000/1651612958-GettyImages-916432942-copy.jpg',
#    'publishedAt': '2022-05-03T23:01:00Z',
#    'content': 'Last week, the Senate of the Republic in Mexico organized a forum to raise awareness about the use of cryptocurrencies and to analyze and trigger their growth. The senators must have seen something, … [+1406 chars]'},
#   {'source': {'id': None, 'name': 'MakeUseOf'},
#    'author': 'Katie Rees',
#    'title': 'What Is Zilliqa? Will It Surpass Ethereum?',
#    'description': 'It has an ever-growing ecosystem, supports staking and NFTs, and is growing in popularity. So, what is Zilliqa?',
#    'url': 'https://www.makeuseof.com/what-is-zilliqa/',
#    'urlToImage': 'https://static1.makeuseofimages.com/wordpress/wp-content/uploads/2022/05/zilliqa-earth-1.jpg',
#    'publishedAt': '2022-05-15T16:00:14Z',
#    'content': "The cryptocurrency industry isn't just about buying and selling coins and tokens. You can do myriad other things with your crypto, and thousands of crypto enthusiasts want to take their passion a ste… [+6847 chars]"},
#   {'source': {'id': None, 'name': 'Entrepreneur'},
#    'author': 'Madeline Garfinkle',
#    'title': 'Rough Monday For Bitcoin: 5.2% Drop in 24 Hours',
#    'description': 'After its fifth consecutive day of drops, Bitcoin is down more than 50% since its peak in November.',
#    'url': 'https://www.entrepreneur.com/article/427129',
#    'urlToImage': 'https://assets.entrepreneur.com/content/3x2/2000/1652111042-GettyImages-1339026234.jpg',
#    'publishedAt': '2022-05-09T15:00:00Z',
#    'content': 'As of Monday\xa0morning, Bitcoin is down to $32,940, a drop that marks a steep fall of more than 50% since its all-time high of $68,990 in November and Bitcoin isnt the only digital currency taking a di… [+1414 chars]'},
#   {'source': {'id': 'the-next-web', 'name': 'The Next Web'},
#    'author': 'The Conversation',
#    'title': 'Here’s why Europe needs a digital euro',
#    'description': 'The European Central Bank and its counterparts in the UK, US, China, and India are exploring a new form of state-backed money built on similar online ledger technology to cryptocurrencies such as bitcoin and ethereum. So-called central bank digital currencies…',
#    'url': 'https://thenextweb.com/news/why-europe-needs-digital-euro',
#    'urlToImage': 'https://img-cdn.tnwcdn.com/image/hardfork?filter_last=1&fit=1280%2C640&url=https%3A%2F%2Fcdn0.tnwcdn.com%2Fwp-content%2Fblogs.dir%2F1%2Ffiles%2F2022%2F05%2Fdigital-euro.png&signature=3085de42c546a09a62bb13e8a4c2bc26',
#    'publishedAt': '2022-05-22T13:05:36Z',
#    'content': 'The European Central Bank and its counterparts in the UK, US, China, and India are exploring a new form of state-backed money built on similar online ledger technology to cryptocurrencies such as bit… [+7410 chars]'},
#   {'source': {'id': None, 'name': 'Cryptolka.com'},
#    'author': 'cryptolka',
#    'title': 'MetaMask to launch its own token and DAO',
#    'description': ' MetaMask to launch its own token and DAO. The popular Ethereum wallet “MetaMask” is officially launching its own token, as confirmed by Consensys CEO Joseph Lubin. The team will also reportedly launch a decentralized autonomous organization (DAO) for fundi…',
#    'url': 'https://www.cryptolka.com/🔥-metamask-to-launch-its-own-token-and-dao/',
#    'urlToImage': 'https://www.cryptolka.com/image/2022/03/Metamask-Token-Cryptolka.jpg',
#    'publishedAt': '2022-05-22T12:56:30Z',
#    'content': 'MetaMask to launch its own token and DAO.\r\nThe popular Ethereum wallet MetaMask is officially launching its own token, as confirmed by Consensys CEO Joseph Lubin. The team will also reportedly launch… [+496 chars]'},
#   {'source': {'id': None, 'name': 'The Guardian'},
#    'author': 'Alex Hern',
#    'title': '$7.6bn of ‘stablecoin’ tether redeemed since start of crypto crisis',
#    'description': 'Figures suggest company has paid out more than total cash on hand, as terra backers prepare relaunchDigital investors have withdrawn savings in the “stablecoin” tether worth $7.6bn since the cryptocurrency crisis began last week, suggesting the company has pa…',
#    'url': 'https://amp.theguardian.com/technology/2022/may/16/stablecoin-tether-redeemed-crypto-crisis-terra',
#    'urlToImage': 'https://i.guim.co.uk/img/media/ed7cd8cd63b5e9292e420fedea419d72de26d813/0_398_6002_3603/master/6002.jpg?width=1200&height=630&quality=85&auto=format&fit=crop&overlay-align=bottom%2Cleft&overlay-width=100p&overlay-base64=L2ltZy9zdGF0aWMvb3ZlcmxheXMvdGctZGVmYXVsdC5wbmc&enable=upscale&s=45c2360bba42dde961b6e201c5640b06',
#    'publishedAt': '2022-05-16T15:01:58Z',
#    'content': 'Digital investors have withdrawn savings in the stablecoin tether worth $7.6bn since the cryptocurrency crisis began last week, suggesting the company has paid out a sum almost twice its total cash h… [+5273 chars]'},
#   {'source': {'id': None, 'name': 'The Guardian'},
#    'author': 'Alex Hern Technology editor',
#    'title': 'Crypto crash unlikely to reduce its climate impact, expert says',
#    'description': 'Enormous energy consumption has barely reduced despite $1tn being wiped off the sectorThe crypto crash will not reduce the sector’s climate impact any time soon, an economist has warned, even though the environmental footprint of digital currencies is in theo…',
#    'url': 'https://amp.theguardian.com/technology/2022/may/18/crypto-crash-unlikely-to-reduce-its-climate-impact-expert-says',
#    'urlToImage': 'https://i.guim.co.uk/img/media/5e2c92cf82aaf1cb540d6d078a8ff4d4085a8c37/116_299_5187_3112/master/5187.jpg?width=1200&height=630&quality=85&auto=format&fit=crop&overlay-align=bottom%2Cleft&overlay-width=100p&overlay-base64=L2ltZy9zdGF0aWMvb3ZlcmxheXMvdGctZGVmYXVsdC5wbmc&enable=upscale&s=cd301a27bef4b29b454ee049a3bbfcd7',
#    'publishedAt': '2022-05-18T15:25:40Z',
#    'content': 'The crypto crash will not reduce the sectors climate impact any time soon, an economist has warned, even though the environmental footprint of digital currencies is in theory set by their market valu… [+4874 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'hrobertson@businessinsider.com (Harry Robertson)',
#    'title': 'Stablecoin tether breaks its peg and drops to $0.95 as panic hits crypto markets after collapse of TerraUSD',
#    'description': 'Tether — which is supposed to be worth $1 — suffered its biggest drop in over a year as it dropped as low as $0.945.',
#    'url': 'https://markets.businessinsider.com/news/currencies/tether-depeg-dollar-fall-cryptocurrency-market-panic-terrausd-luna-2022-5',
#    'urlToImage': 'https://i.insider.com/627cc9a3dd983300191caa61?width=1200&format=jpeg',
#    'publishedAt': '2022-05-12T09:02:06Z',
#    'content': "Tether, the world's biggest stablecoin, tumbled as low as $0.94 on Thursday as panic spread across crypto markets after a dramatic plunge in the TerraUSD and luna tokens.\r\nThe stablecoin fell to $0.9… [+2101 chars]"},
#   {'source': {'id': None, 'name': 'Slashdot.org'},
#    'author': 'msmash',
#    'title': 'Instagram To Start Testing NFTs With Select Creators this Week',
#    'description': 'Instagram head Adam Mosseri announced today that the platform is going to start testing NFTs with select creators in the United States this week. From a report: Mosseri noted that there will be no fees associated with posting or sharing a digital collectible …',
#    'url': 'https://tech.slashdot.org/story/22/05/09/1526228/instagram-to-start-testing-nfts-with-select-creators-this-week',
#    'urlToImage': 'https://a.fsdn.com/sd/topics/social_64.png',
#    'publishedAt': '2022-05-09T15:26:00Z',
#    'content': "I looked inside the blockchain and the art I purchased was Not Fucking There. All I found was a URL that now returns 404. But I'm sure that I can resell it for more than I paid, most certainly. Just … [+148 chars]"},
#   {'source': {'id': None, 'name': 'Entrepreneur'},
#    'author': 'Amanda Breen',
#    'title': 'NFTs Are Coming to Your Social-Media Feed This Week, Says Mark Zuckerberg',
#    'description': 'The broader implications for creators remain to be seen.',
#    'url': 'https://www.entrepreneur.com/article/427233',
#    'urlToImage': 'https://assets.entrepreneur.com/content/3x2/2000/1652194729-GettyImages-1325758241.jpg',
#    'publishedAt': '2022-05-10T14:56:00Z',
#    'content': 'Earlier this year, Meta CEO Mark Zuckerberg revealed the company was toying with the idea of bringing NFTs to its social-media platform Instagram, though he declined to comment on exactly how and whe… [+1844 chars]'},
#   {'source': {'id': None, 'name': 'MakeUseOf'},
#    'author': 'Jerome Davidson',
#    'title': 'What Is Algorand? Why Is It Called the "Ethereum Killer?"',
#    'description': "Algorand is scalable, has smart contracts, and supports DeFi. It's no wonder some people prefer it over Ethereum.",
#    'url': 'https://www.makeuseof.com/what-is-algorand/',
#    'urlToImage': 'https://static1.makeuseofimages.com/wordpress/wp-content/uploads/2022/05/crypto-coins.jpg',
#    'publishedAt': '2022-06-03T21:45:14Z',
#    'content': 'Algorand is a smart contract platform that enables developers to build scalable decentralized applications.\r\nThe Algorand network was founded in 2017 by Silvio Micali, a professor at the Massachusett… [+4778 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'insider@insider.com (Paul Kim)',
#    'title': 'Cryptocurrency is crashing. What does that mean for you?',
#    'description': 'The cryptocurrency market is in turmoil after two stablecoins destabilized and Coinbase announced net losses far greater than projected.',
#    'url': 'https://www.businessinsider.com/personal-finance/crypto-crash',
#    'urlToImage': 'https://i.insider.com/627eced89147a30018b4758b?width=1200&format=jpeg',
#    'publishedAt': '2022-05-13T23:04:06Z',
#    'content': "The cryptocurrency world has had a rough May so far.\xa0\r\nSince the start of the month, cryptocurrency has lost $600 billion of value. Bitcoin dropped to prices that haven't been seen since 2020, briefl… [+5071 chars]"},
#   {'source': {'id': None, 'name': 'Entrepreneur'},
#    'author': 'Masha Prusso',
#    'title': 'Think Marketplaces, Not Businesses: 3 Lucrative Industries Disrupted By Crypto',
#    'description': "Cryptocurrencies have moved well beyond replacing fiat currency. They are being specifically applied to distinct industries to have maximum impact -\xa0so here's why you should consider diversifying your crypto portfolio.",
#    'url': 'https://www.entrepreneur.com/article/424002',
#    'urlToImage': 'https://assets.entrepreneur.com/content/3x2/2000/1651697414-GettyImages-1369169431.jpg',
#    'publishedAt': '2022-05-10T16:30:00Z',
#    'content': 'Smart entrepreneurs will always look towards infrastructures and marketplaces as opposed to businesses. In Web2, its the difference between creating Google and creating an online website visited thro… [+5316 chars]'},
#   {'source': {'id': None, 'name': 'Entrepreneur'},
#    'author': 'Yakup Özkardes-Cheung',
#    'title': 'The New Creative Economy Within Web 3.0',
#    'description': 'Web 3.0 will be a place where anyone can share information without worrying about censorship, and people can create content without worrying about getting paid for it.',
#    'url': 'https://www.entrepreneur.com/article/423776',
#    'urlToImage': 'https://assets.entrepreneur.com/content/3x2/2000/1651509960-GettyImages-1388034008.jpg',
#    'publishedAt': '2022-05-14T17:00:00Z',
#    'content': 'What is Web 3.0, really?\r\nWeb 3.0 is an abbreviation of the third generation of the World Wide Web. It is a term coined by Tim Berners-Lee and describes an internet that is not only more interactive,… [+4033 chars]'},
#   {'source': {'id': None, 'name': 'Entrepreneur'},
#    'author': 'Entrepreneur en Español',
#    'title': "Bored and Hungry, the fast food restaurant that uses NFT's from the Bored Ape Yacht Collection for its image",
#    'description': 'The most famous apes of the digital world are very present in a fast food place in California.',
#    'url': 'https://www.entrepreneur.com/article/427161',
#    'urlToImage': 'https://assets.entrepreneur.com/content/3x2/2000/1652112003-GettyImages-1390557351.jpg',
#    'publishedAt': '2022-05-09T17:39:00Z',
#    'content': "No, it is not a restaurant where, in addition to hamburgers, you can buy NFT's (non-fungible tokens, that is, digital assets that represent something unique). Bored and Hungry is just a fast food res… [+1891 chars]"},
#   {'source': {'id': 'ars-technica', 'name': 'Ars Technica'},
#    'author': 'Timothy B. Lee',
#    'title': 'Bitcoin plunges to lowest price since 2020 amid broader sell-off',
#    'description': 'The "stablecoin" Tether briefly lost its peg to the dollar on Thursday morning.',
#    'url': 'https://arstechnica.com/tech-policy/2022/05/bitcoin-plunges-to-lowest-price-since-2020-amid-broader-sell-off/',
#    'urlToImage': 'https://cdn.arstechnica.net/wp-content/uploads/2022/05/GettyImages-876199432-760x380.jpg',
#    'publishedAt': '2022-05-12T21:40:52Z',
#    'content': "23 with 16 posters participating, including story author\r\nThe price of one Bitcoin briefly fell below $27,000 on Thursday morning, the lowest price for the cryptocurrency since 2020. The world's lead… [+2982 chars]"},
#   {'source': {'id': None, 'name': 'Medium'},
#    'author': 'GOKE ADEKUNLE; #Wolfwords',
#    'title': 'Analysing Data in Web3 with SQL',
#    'description': 'I want to believe, you aren’t here by mistake. You want to know how to be an efficient data analyst in web3. Are you trying to build your Web3 analytics dashboard or just getting interested in web3…',
#    'url': 'https://thisgoke.medium.com/analysing-data-in-web3-with-sql-6c205fff6364',
#    'urlToImage': 'https://miro.medium.com/max/1200/1*BDETKOd8JkI5PpGdm8SVgQ.jpeg',
#    'publishedAt': '2022-05-20T14:36:35Z',
#    'content': 'Analysing Data In Web3 with SQL\r\nI want to believe, you arent here by mistake. You want to know how to be an efficient data analyst in web3. Are you trying to build your Web3 analytics dashboard or j… [+11438 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Elizabeth Lopatto',
#    'title': 'How the Anchor protocol helped sink Terra',
#    'description': 'If a 20 percent interest rate sounds too good to be true, it probably is. Ultimately, Anchor weighed its investors down when Terra ran aground.',
#    'url': 'https://www.theverge.com/2022/5/20/23131647/terra-luna-do-kwon-stablecoin-anchor',
#    'urlToImage': 'https://cdn.vox-cdn.com/thumbor/IVL0qTILLdUK0KGUt8E3CQahHro=/0x146:2040x1214/fit-in/1200x630/cdn.vox-cdn.com/uploads/chorus_asset/file/22413649/acastro_210329_1777_nft_0004.jpg',
#    'publishedAt': '2022-05-20T15:20:00Z',
#    'content': 'Illustration by Alex Castro / The Verge\r\n\n \n\n If Do Kwon didn’t exist, someone would have had to invent him. For instance, there’s the bets he made — worth $11 million in total and held in escrow by … [+8192 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Breakingviews - Smaller, warmer Davos confronts a siloed world - Reuters',
#    'description': 'The World Economic Forum is showing signs of a more siloed world. Political, business and financial leaders and their entourages are convening in Davos, Switzerland this week after a delay of more than two years. Pandemic, war, and the unusual spring slot hel…',
#    'url': 'https://www.reuters.com/breakingviews/smaller-warmer-davos-confronts-siloed-world-2022-05-23/',
#    'urlToImage': 'https://www.reuters.com/resizer/TpLPsZMUdnAtVif7YeQJ9h0AGzY=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/DVKGIGKQUROXJOX2UPABZD4PWA.jpg',
#    'publishedAt': '2022-05-23T09:10:00Z',
#    'content': 'DAVOS, Switzerland, May 23 (Reuters Breakingviews) - The World Economic Forum is showing signs of a more siloed world. Political, business and financial leaders and their entourages are convening in … [+3289 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Bitcoin lures inflation-weary Argentines despite crypto crash - Reuters',
#    'description': 'In the Crypstation cafe in downtown Buenos Aires, trendy young Argentines order their lattes and pastries surrounded by screens with real-time cryptocurrency price quotes and a huge neon Bitcoin logo. The bill can be paid in digital money, too.',
# ...
#   {'source': {'id': None, 'name': 'Entrepreneur'},
#    'author': 'Tanveer Zafar',
#    'title': 'The Future is DeFi: Going Beyond the Traditional Norm',
#    'description': 'Decentralized finance is going to continue taking the world by storm.',
#    'url': 'https://www.entrepreneur.com/article/426780',
#    'urlToImage': 'https://assets.entrepreneur.com/content/3x2/2000/1652980806-GettyImages-1356301667.jpg',
#    'publishedAt': '2022-05-30T14:00:00Z',
#    'content': 'The idea of decentralized finance was born around 2017, a few years after the launch of the Ethereum Blockchain. Since then, the DeFi space has increasingly attracted attention from many different ke… [+5023 chars]'},
#   {'source': {'id': None, 'name': 'The Business of Fashion'},
#    'author': 'Robert Williams',
#    'title': 'Gucci to Accept Cryptocurrency',
#    'description': 'The Italian megabrand is set to accept payment in Bitcoin, Ethereum, Dogecoin and other digital currencies at select US stores.',
#    'url': 'https://www.businessoffashion.com/articles/luxury/gucci-to-accept-cryptocurrency/',
#    'urlToImage': 'https://img.businessoffashion.com/resizer/7k9ZxDVuItxfr2-bgIOMdUOBehs=/1200x630/filters:format(jpg):quality(70):focal(4903x880:4913x890)/cloudfront-eu-central-1.images.arcpublishing.com/businessoffashion/5GK76QPVRFHLHEW5ZTK3E5PFSM.jpg',
#    'publishedAt': '2022-05-05T00:20:48Z',
#    'content': 'Clients of Italian luxury giant Gucci will soon be able to pay for products in cryptocurrency at certain US retail stores. \r\nGucci will accept 10 crypto currencies including Bitcoin, Ethereum and Dog… [+1527 chars]'},
#   {'source': {'id': None, 'name': 'Motley Fool'},
#    'author': 'newsfeedback@fool.com (Keegan Francis)',
#    'title': 'Why Bitcoin and Ethereum Are Different Investments',
#    'description': "Rather than competing with one another for market share, Bitcoin and Ethereum complement each other's growth.",
#    'url': 'https://www.fool.com/cryptocurrency/2022/06/01/why-bitcoin-and-ethereum-are-different-investments/',
#    'urlToImage': 'https://g.foolcdn.com/editorial/images/681749/bitcoin-defi.jpeg',
#    'publishedAt': '2022-06-01T14:45:00Z',
#    'content': 'Which is a better investment? Bitcoin(BTC -1.64%) or Ethereum(ETH -2.82%)? The truth is that these two cryptocurrencies are fundamentally different. They perform different functions and have differen… [+3696 chars]'},
#   {'source': {'id': None, 'name': 'MarketWatch'},
#    'author': 'Chris Matthews',
#    'title': 'Crypto: MakerDAO’s Rune Christensen says Terra was ‘long overdue’ to collapse, calls for rules on stablecoins',
#    'description': 'The collapse of the stablecoin TerraUSD was a bittersweet vindication for Rune Christensen, CEO cofounder of the decentralized crypto project MakerDao.',
#    'url': 'https://www.marketwatch.com/story/makerdaos-rune-christensen-says-terra-was-long-overdue-to-collapse-calls-for-rules-on-stablecoins-11653065793',
#    'urlToImage': 'https://images.mktw.net/im-547739/social',
#    'publishedAt': '2022-05-20T16:56:00Z',
#    'content': 'The collapse of the stablecoin TerraUSD was a bittersweet vindication for Rune Christensen, CEO cofounder of the decentralized crypto project MakerDao, as he had a long track record of arguing that T… [+7144 chars]'},
#   {'source': {'id': None, 'name': 'Motley Fool'},
#    'author': 'newsfeedback@fool.com (Neil Patel)',
#    'title': '1 Cryptocurrency That Could Dwarf Ethereum',
#    'description': 'Thoughtfully trying to solve the scalability issue could mean huge upside for investors.',
#    'url': 'https://www.fool.com/investing/2022/05/13/1-cryptocurrency-that-could-dwarf-ethereum/',
#    'urlToImage': 'https://g.foolcdn.com/editorial/images/678912/gettyimages-1347340865-1.jpg',
#    'publishedAt': '2022-05-13T13:15:00Z',
#    'content': "Despite the recent turmoil rattling the crypto market, over the past five years, Ethereum(ETH 10.54%) has generated an astronomical return of 2,560%. You'd be hard-pressed to find a financial asset w… [+3549 chars]"},
#   {'source': {'id': None, 'name': 'Motley Fool'},
#    'author': 'newsfeedback@fool.com (Travis Hoium)',
#    'title': 'Is Solana Kicking Ethereum to the Curb?',
#    'description': "Ethereum's digital economy may be limited because of its inability to scale.",
#    'url': 'https://www.fool.com/investing/2022/05/12/is-solana-kicking-ethereum-to-the-curb/',
#    'urlToImage': 'https://g.foolcdn.com/editorial/images/679450/gettyimages-1317587887.jpg',
#    'publishedAt': '2022-05-12T11:00:00Z',
#    'content': 'The limits that Ethereum(ETH -18.88%) has on how it can scale today could be a serious challenge that allows competing blockchains to more fully develop in its place. In this Motley Fool Live segment… [+2000 chars]'},
#   {'source': {'id': None, 'name': 'Motley Fool'},
#    'author': 'newsfeedback@fool.com (Jon Quast)',
#    'title': 'This Ethereum Competitor Is Worth $5.25 Billion',
#    'description': 'Avalanche is currently the 10th largest cryptocurrency by market cap.',
#    'url': 'https://www.fool.com/investing/2022/05/12/this-ethereum-competitor-is-worth-525-billion/',
#    'urlToImage': 'https://g.foolcdn.com/editorial/images/679446/gettyimages-907902702_T1XF7UD.jpg',
#    'publishedAt': '2022-05-12T11:00:00Z',
#    'content': 'Ava Labs, the team behind Avalanche(AVAX -23.35%), is sitting on a lot of money for a crypto company. In this Motley Fool Live segment from "The Crypto Show," recorded April 20, Fool.com contributors… [+3005 chars]'},
#   {'source': {'id': None, 'name': 'Motley Fool'},
#    'author': 'newsfeedback@fool.com (Keith Speights)',
#    'title': 'Could Ethereum Soar 26X by 2030?',
#    'description': "It's possible -- but not necessarily probable.",
#    'url': 'https://www.fool.com/investing/2022/06/03/could-ethereum-soar-26x-by-2030/',
#    'urlToImage': 'https://g.foolcdn.com/editorial/images/681031/ethereum-globe.jpg',
#    'publishedAt': '2022-06-03T09:52:00Z',
#    'content': "When I was a kid, I always glanced at the tabloids on the rack at the grocery store's checkout counter. The headlines often referenced celebrities and UFOs (not necessarily in different stories). Ano… [+3668 chars]"},
#   {'source': {'id': 'bloomberg', 'name': 'Bloomberg'},
#    'author': 'Jialiang David Pan',
#    'title': 'Battered DeFi Investors Put Their Hopes in Ethereum Revamp',
#    'description': 'Decentralized-finance investors are betting on Ethereum’s revamp to help thaw out the market’s more than two-months-long crypto winter.',
#    'url': 'https://www.bloomberg.com/news/articles/2022-05-28/battered-defi-investors-put-their-hopes-in-ethereum-revamp',
#    'urlToImage': 'https://assets.bwbx.io/images/users/iqjWHBFdfxIU/iwPKasA4av3U/v1/1200x800.jpg',
#    'publishedAt': '2022-05-28T14:00:00Z',
#    'content': 'Decentralized-finance investors are betting on Ethereums revamp to help thaw out the markets more than two-months-long crypto winter.\xa0\r\nThe DeFi sector, where investors earn yields by trading and sta… [+401 chars]'},
#   {'source': {'id': None, 'name': 'Motley Fool'},
#    'author': 'newsfeedback@fool.com (Will Ebiefung)',
#    'title': '2 Top Cryptocurrencies to Buy and Never Sell',
#    'description': 'These two "Ethereum killers" look poised for sustainable success.',
#    'url': 'https://www.fool.com/investing/2022/05/10/2-top-cryptocurrencies-to-buy-and-never-sell/',
#    'urlToImage': 'https://g.foolcdn.com/editorial/images/678612/gettyimages-1323758599.jpg',
#    'publishedAt': '2022-05-10T10:45:00Z',
#    'content': 'Cryptocurrency is a speculative asset class, but leading blockchains like\xa0Solana\xa0(SOL -4.10%) and\xa0Cardano\xa0(ADA 0.02%) have fundamental advantages over rivals in sophistication and potential uses. Let… [+3203 chars]'},
#   {'source': {'id': None, 'name': 'Motley Fool'},
#    'author': 'newsfeedback@fool.com (Will Ebiefung)',
#    'title': 'Market Plunge 2022: 2 Top Cryptos to Buy Cheap',
#    'description': 'Bitcoin and Ethereum have what it takes to bounce back.',
#    'url': 'https://www.fool.com/investing/2022/05/17/market-plunge-2022-2-top-cryptos-to-buy-cheap/',
#    'urlToImage': 'https://g.foolcdn.com/editorial/images/680042/gettyimages-904127288.jpg',
#    'publishedAt': '2022-05-17T12:00:00Z',
#    'content': "With the crypto market down a jaw-dropping 41% to $1.3 trillion year to date, this isn't a correction -- it's a crash. But while it's tempting to rush for the exits, this might turn into an opportuni… [+2952 chars]"},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'rhouston@businessinsider.com (Rickie Houston, CEPF)',
#    'title': 'Coinbase vs. Coinbase Pro: How to choose between the basic and advanced crypto accounts',
#    'description': 'The basic Coinbase account best suits beginners, but advanced traders can upgrade to Coinbase Pro without any extra fees to get more tools and data.',
#    'url': 'https://www.businessinsider.com/personal-finance/coinbase-vs-coinbase-pro',
#    'urlToImage': 'https://i.insider.com/62854eb9e19cda0018867e4c?width=1200&format=jpeg',
#    'publishedAt': '2022-05-18T20:49:01Z',
#    'content': 'Bottom line:\xa0The basic Coinbase account best suits beginner and intermediate-level traders who want a simple interface and access to a variety of crypto products. Coinbase Pro, on the other hand, is … [+5803 chars]'},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'insider@insider.com (Hanna Horvath)',
#    'title': '3 things to consider before adding bitcoin to your retirement portfolio, according to a financial planner',
#    'description': 'If you want to add bitcoin to your retirement portfolio, be sure you understand the risks involved and consider how close you are to retiring.',
#    'url': 'https://www.businessinsider.com/personal-finance/things-to-consider-before-adding-bitcoin-retirement-2022-5',
#    'urlToImage': 'https://i.insider.com/628254239147a30018b4854b?width=1200&format=jpeg',
#    'publishedAt': '2022-05-16T14:57:15Z',
#    'content': "What was once a niche investment is now becoming mainstream a vast majority of adults have at least heard about cryptocurrency, and 16% say they've invested or traded crypto. Now, the investment may … [+4441 chars]"},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'insider@insider.com (Paul Kim)',
#    'title': 'The Howey test: A set of rules that determine if an investment is a security',
#    'description': 'The Howey test is a set of standards that determine if a transaction is considered an investment contract or a security.',
#    'url': 'https://www.businessinsider.com/personal-finance/howey-test',
#    'urlToImage': 'https://i.insider.com/628ffa1a14f00200180fed8e?width=1200&format=jpeg',
#    'publishedAt': '2022-05-31T18:58:10Z',
#    'content': 'When you make an investment, you put down some money in the hopes that it will see returns. In doing so, you also take on a certain amount of risk. Some investments are riskier than others, and some … [+5736 chars]'},
#   {'source': {'id': None, 'name': 'StockNews.com'},
#    'author': 'Aditi Ganguly',
#    'title': 'Is GameStop Stock a Buy After Its Recent Launch of a Digital Wallet for Cryptos and NFTs?',
#    'description': 'Popular meme stock GameStop (GME) has been gaining momentum again on its latest digital crypto and NFT wallet launch last week. However, given the company’s bleak earnings growth prospects and...',
#    'url': 'https://stocknews.com/news/gme-odp-cdnaf-is-gamestop-stock-a-buy-after-its-recent-launch-of/',
#    'urlToImage': 'https://assets.entrepreneur.com/providers/stocknews/hero-image-stocknews-428551.jpeg',
#    'publishedAt': '2022-05-31T11:45:12Z',
#    'content': 'Popular meme stock GameStop (GME) has been gaining momentum again on its latest digital crypto and NFT wallet launch last week. However, given the companys bleak earnings growth prospects and bearish… [+5033 chars]'},
#   {'source': {'id': None, 'name': '9to5Mac'},
#    'author': 'Zac',
#    'title': 'Instagram investing in NFT support with digital collectibles feature, available now for select creators',
#    'description': 'Instagram, the photo sharing social network that lacks the resources required to develop an iPad app, is developing support for NFTs. The Facebook-turned-Meta-owned service admits that supporting decentralized technology on a centralized platform is a huge ef…',
#    'url': 'https://9to5mac.com/2022/05/09/instagram-not-for-tablets-nft/',
#    'urlToImage': 'https://i0.wp.com/9to5mac.com/wp-content/uploads/sites/6/2022/05/instagram-nfts.jpg?resize=1200%2C628&quality=82&strip=all&ssl=1',
#    'publishedAt': '2022-05-09T14:15:17Z',
#    'content': 'Instagram, the photo sharing social network that lacks the resources required to develop an iPad app, is developing support for NFTs. The Facebook-turned-Meta-owned service admits that supporting dec… [+1671 chars]'},
#   {'source': {'id': None, 'name': 'MarketWatch'},
#    'author': 'Emily Bary',
#    'title': ': Coinbase stock falls toward all-time low as crypto trading falls off',
#    'description': 'Crypto-trading app reports 2.2 million fewer people were trading in the first quarter than at the end of 2021, executives say, ‘We believe these market conditions are not permanent’',
#    'url': 'https://www.marketwatch.com/story/coinbase-stock-falls-toward-all-time-low-as-crypto-trading-falls-off-11652215173',
#    'urlToImage': 'https://images.mktw.net/im-341351/social',
#    'publishedAt': '2022-05-10T20:39:00Z',
#    'content': 'Coinbase Global Inc. swung to a loss in its most recent quarter and posted lower-than-expected revenue as it lost 2.2 million crypto traders from its platform, citing the impacts of lower volatility … [+2597 chars]'},
#   {'source': {'id': None, 'name': 'MarketWatch'},
#    'author': 'Weston Blasi',
#    'title': 'Key Words: Mark Cuban: ‘Crypto is going through the lull that the internet went through’',
#    'description': 'Cuban echoed comparisons of slumping crypto prices and NFT interest to the dot-com bubble',
#    'url': 'https://www.marketwatch.com/story/mark-cuban-crypto-is-going-through-the-lull-that-the-internet-went-through-11652117112',
#    'urlToImage': 'https://images.mktw.net/im-540582/social',
#    'publishedAt': '2022-05-09T17:25:00Z',
#    'content': 'Billionaire entrepreneur Mark Cuban thinks that cryptocurrency is on the same downswing that tech and internet companies hit in the early 2000s.Cuban addressed the slump in a viral Twitter \r\n TWTR,\r\n… [+3199 chars]'},
#   {'source': {'id': None, 'name': 'Motley Fool'},
#    'author': 'newsfeedback@fool.com (Keith Speights)',
#    'title': 'Why Staking Ethereum Could Be an Absolutely Brilliant Way to Earn Passive Income',
#    'description': 'Staking is a great move if the long-term prospects for Ethereum remain strong.',
#    'url': 'https://www.fool.com/investing/2022/05/16/staking-ethereum-earn-passive-income/',
#    'urlToImage': 'https://g.foolcdn.com/editorial/images/678502/ethereum-globe.jpg',
#    'publishedAt': '2022-05-16T09:52:00Z',
#    'content': "Imagine kicking back while watching a great movie and making money the entire time. That's exactly what passive income can enable you to do.\xa0\r\nThere are several alternatives for generating income tha… [+3197 chars]"},
#   {'source': {'id': None, 'name': 'Motley Fool'},
#    'author': 'newsfeedback@fool.com (Chris MacDonald)',
#    'title': 'The Ethereum Merge Is Coming Sooner Than Expected -- Mark June 8 on the Calendar',
#    'description': 'Anticipation around the Ethereum merge is building, with a key update provided today.',
#    'url': 'https://www.fool.com/investing/2022/05/20/the-ethereum-merge-is-coming-sooner-than-expected/',
#    'urlToImage': 'https://g.foolcdn.com/editorial/images/681098/ether.jpg',
#    'publishedAt': '2022-05-20T13:53:09Z',
#    'content': "What happened\r\nThe world's second-largest cryptocurrency by market capitalization,\xa0Ethereum\xa0(ETH 3.16%), continues to be among the most-watched tokens in the market. Today, that's no different, with … [+2123 chars]"}]}

# %%
# Create the sentiment scores DataFrame
eth_sentiments = []

for article in eth_headlines["articles"]:
    try:
        Date = article["publishedAt"]
        text = article["content"]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        eth_sentiments.append({
            "Date": Date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    
eth_df = pd.DataFrame(eth_sentiments)   
eth_df["Date"] = pd.to_datetime(eth_df["Date"])
eth_df = eth_df.set_index("Date")
eth_df = eth_df.sort_index()
eth_df
# Out:
#                            compound  positive  negative  neutral
# Date
# 2022-05-03 05:15:00+00:00   -0.4404     0.000     0.088    0.912
# 2022-05-03 10:00:00+00:00    0.2732     0.170     0.118    0.713
# 2022-05-03 18:23:55+00:00   -0.4404     0.064     0.139    0.797
# 2022-05-03 23:01:00+00:00    0.3818     0.073     0.000    0.927
# 2022-05-04 02:32:00+00:00   -0.2732     0.000     0.055    0.945
# ...                             ...       ...       ...      ...
# 2022-06-03 14:00:00+00:00    0.4404     0.075     0.000    0.925
# 2022-06-03 16:11:26+00:00   -0.5574     0.000     0.098    0.902
# 2022-06-03 20:26:26+00:00    0.4404     0.122     0.000    0.878
# 2022-06-03 21:34:57+00:00    0.9169     0.301     0.000    0.699
# 2022-06-03 21:45:14+00:00    0.4019     0.088     0.000    0.912
#
# [100 rows x 4 columns]

# %%
eth_df = eth_df.resample('15min').mean().ffill()
eth_df.index = eth_df.index.tz_localize(None)
eth_df
# Out:
#                      compound  positive  negative  neutral
# Date
# 2022-05-03 05:15:00   -0.4404     0.000     0.088    0.912
# 2022-05-03 05:30:00   -0.4404     0.000     0.088    0.912
# 2022-05-03 05:45:00   -0.4404     0.000     0.088    0.912
# 2022-05-03 06:00:00   -0.4404     0.000     0.088    0.912
# 2022-05-03 06:15:00   -0.4404     0.000     0.088    0.912
# ...                       ...       ...       ...      ...
# 2022-06-03 20:45:00    0.4404     0.122     0.000    0.878
# 2022-06-03 21:00:00    0.4404     0.122     0.000    0.878
# 2022-06-03 21:15:00    0.4404     0.122     0.000    0.878
# 2022-06-03 21:30:00    0.9169     0.301     0.000    0.699
# 2022-06-03 21:45:00    0.4019     0.088     0.000    0.912
#
# [3043 rows x 4 columns]

# %%
#eth_df.index = eth_df.index.round('15min')
#eth_df.index = eth_df.index.tz_localize(None)
#eth_df

# %%
# Creacting a binary response for the tsla stock
eth_df['comp_score'] = eth_df['compound'].apply(lambda c: '1' if c >=0 else '0')

eth_df.tail()
len(eth_df)
# Out:
# 3043

# %%
eth_trading_data = pd.read_csv(
    Path("eth_data_15m.csv"), 
    index_col="Date", 
    infer_datetime_format=True, 
    parse_dates=True
)

# Review the DataFrame
eth_trading_data.tail(20)
# Out:
#                         Open     High      Low    Close  Volume_base  \
# Date
# 2022-06-03 23:15:00  2472.51  2473.01  2463.74  2467.04       5.6838
# 2022-06-03 23:30:00  2467.86  2467.86  2460.11  2461.13       7.4919
# 2022-06-03 23:45:00  2460.70  2462.00  2455.84  2460.50      14.8037
# 2022-06-04 00:00:00  2460.70  2463.43  2455.51  2461.02       6.0190
# 2022-06-04 00:15:00  2461.72  2467.48  2457.39  2465.52       9.5615
# 2022-06-04 00:30:00  2465.44  2466.83  2460.91  2464.30       5.4604
# 2022-06-04 00:45:00  2464.73  2465.59  2459.47  2462.49       5.8797
# 2022-06-04 01:00:00  2460.87  2462.66  2455.84  2461.15      16.0249
# 2022-06-04 01:15:00  2461.41  2464.50  2444.85  2447.29      13.1788
# 2022-06-04 01:30:00  2450.11  2453.02  2443.90  2443.90      17.6439
# 2022-06-04 01:45:00  2444.03  2448.64  2440.22  2445.50       9.4798
# 2022-06-04 02:00:00  2445.46  2446.67  2440.49  2441.54       9.5575
# 2022-06-04 02:15:00  2440.97  2445.47  2437.57  2440.42      18.5517
# 2022-06-04 02:30:00  2440.89  2442.64  2429.02  2432.63      27.1073
# 2022-06-04 02:45:00  2431.79  2433.14  2425.77  2426.71      13.3282
# 2022-06-04 03:00:00  2429.17  2434.62  2425.40  2434.41      14.9376
# 2022-06-04 03:15:00  2432.15  2439.59  2432.15  2437.77      11.0728
# 2022-06-04 03:30:00  2435.85  2439.40  2434.55  2439.40       7.8100
# 2022-06-04 03:45:00  2437.60  2441.43  2437.22  2439.01       6.8614
# 2022-06-04 04:00:00  2440.26  2440.26  2438.41  2438.41       0.3472
#
#                      Volume_quote
# Date
# 2022-06-03 23:15:00  14036.900324
# 2022-06-03 23:30:00  18453.211935
# 2022-06-03 23:45:00  36431.859497
# 2022-06-04 00:00:00  14812.136029
# 2022-06-04 00:15:00  23547.022158
# 2022-06-04 00:30:00  13455.092709
# 2022-06-04 00:45:00  14473.596952
# 2022-06-04 01:00:00  39404.479382
# 2022-06-04 01:15:00  32329.727192
# 2022-06-04 01:30:00  43217.621894
# 2022-06-04 01:45:00  23186.649468
# 2022-06-04 02:00:00  23361.779552
# 2022-06-04 02:15:00  45270.305203
# 2022-06-04 02:30:00  66033.486632
# 2022-06-04 02:45:00  32382.924638
# 2022-06-04 03:00:00  36283.575626
# 2022-06-04 03:15:00  26977.579387
# 2022-06-04 03:30:00  19032.145132
# 2022-06-04 03:45:00  16740.169335
# 2022-06-04 04:00:00    846.753518

# %%
result_df = pd.merge(eth_trading_data, eth_df, left_index=True, right_index=True)
result_df.head(20)
# Out:
#                         Open     High      Low    Close  Volume_base  \
# Date
# 2022-05-24 18:15:00  2760.49  2780.00  2758.63  2771.13      12.3054
# 2022-05-24 18:30:00  2768.63  2770.72  2759.32  2767.64       5.8977
# 2022-05-24 18:45:00  2764.02  2773.33  2750.00  2752.38       6.1664
# 2022-05-24 19:00:00  2752.73  2752.73  2736.78  2741.71      10.2021
# 2022-05-24 19:15:00  2741.95  2752.35  2740.16  2744.27      13.2652
# 2022-05-24 19:30:00  2746.61  2764.29  2740.11  2756.60       4.2928
# 2022-05-24 19:45:00  2759.47  2769.96  2758.32  2764.01       7.8259
# 2022-05-24 20:00:00  2762.51  2768.42  2755.60  2757.95       8.4111
# 2022-05-24 20:15:00  2757.90  2761.52  2754.08  2757.51       3.3922
# 2022-05-24 20:30:00  2758.58  2760.19  2746.11  2753.33       9.1270
# 2022-05-24 20:45:00  2756.04  2760.00  2752.36  2758.28       4.2095
# 2022-05-24 21:00:00  2760.95  2774.36  2760.95  2769.72       5.0102
# 2022-05-24 21:15:00  2774.02  2782.00  2770.33  2782.00      10.6319
# 2022-05-24 21:30:00  2779.14  2779.14  2773.19  2778.65       2.6362
# 2022-05-24 21:45:00  2775.84  2775.84  2769.92  2775.02       2.2777
# 2022-05-24 22:00:00  2780.00  2794.93  2774.96  2789.25       3.1501
# 2022-05-24 22:15:00  2793.33  2795.44  2787.72  2794.78       9.9447
# 2022-05-24 22:30:00  2794.29  2795.16  2784.03  2785.54       6.2923
# 2022-05-24 22:45:00  2784.27  2785.27  2781.46  2781.46      40.2147
# 2022-05-24 23:00:00  2784.14  2788.80  2783.80  2785.73       4.7260
#
#                       Volume_quote  compound  positive  negative  neutral  \
# Date
# 2022-05-24 18:15:00   34104.134565   -0.1027       0.0      0.04     0.96
# 2022-05-24 18:30:00   16299.100680   -0.1027       0.0      0.04     0.96
# 2022-05-24 18:45:00   17023.241913   -0.1027       0.0      0.04     0.96
# 2022-05-24 19:00:00   27970.991419   -0.1027       0.0      0.04     0.96
# 2022-05-24 19:15:00   36444.307820   -0.1027       0.0      0.04     0.96
# 2022-05-24 19:30:00   11821.300718   -0.1027       0.0      0.04     0.96
# 2022-05-24 19:45:00   21651.950709   -0.1027       0.0      0.04     0.96
# 2022-05-24 20:00:00   23251.867090   -0.1027       0.0      0.04     0.96
# 2022-05-24 20:15:00    9352.798387   -0.1027       0.0      0.04     0.96
# 2022-05-24 20:30:00   25144.147810   -0.1027       0.0      0.04     0.96
# 2022-05-24 20:45:00   11610.023070   -0.1027       0.0      0.04     0.96
# 2022-05-24 21:00:00   13856.455272   -0.1027       0.0      0.04     0.96
# 2022-05-24 21:15:00   29511.719754   -0.1027       0.0      0.04     0.96
# 2022-05-24 21:30:00    7316.414893   -0.1027       0.0      0.04     0.96
# 2022-05-24 21:45:00    6314.617847   -0.1027       0.0      0.04     0.96
# 2022-05-24 22:00:00    8762.838623   -0.1027       0.0      0.04     0.96
# 2022-05-24 22:15:00   27774.835480   -0.1027       0.0      0.04     0.96
# 2022-05-24 22:30:00   17548.694897   -0.1027       0.0      0.04     0.96
# 2022-05-24 22:45:00  111958.026509   -0.1027       0.0      0.04     0.96
# 2022-05-24 23:00:00   13160.292944   -0.1027       0.0      0.04     0.96
#
#                     comp_score
# Date
# 2022-05-24 18:15:00          0
# 2022-05-24 18:30:00          0
# 2022-05-24 18:45:00          0
# 2022-05-24 19:00:00          0
# 2022-05-24 19:15:00          0
# 2022-05-24 19:30:00          0
# 2022-05-24 19:45:00          0
# 2022-05-24 20:00:00          0
# 2022-05-24 20:15:00          0
# 2022-05-24 20:30:00          0
# 2022-05-24 20:45:00          0
# 2022-05-24 21:00:00          0
# 2022-05-24 21:15:00          0
# 2022-05-24 21:30:00          0
# 2022-05-24 21:45:00          0
# 2022-05-24 22:00:00          0
# 2022-05-24 22:15:00          0
# 2022-05-24 22:30:00          0
# 2022-05-24 22:45:00          0
# 2022-05-24 23:00:00          0

# %%
len(result_df)
# Out:
# 975

# %%
#save as a df
result_df.to_csv("qt.csv",index=True)
