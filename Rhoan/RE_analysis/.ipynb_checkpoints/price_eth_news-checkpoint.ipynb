# %%
# Initial imports
import os
import pandas as pd
from dotenv import load_dotenv
import nltk as nltk
import requests
from pathlib import Path
import datetime as dt

nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %matplotlib inline
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
# Read your api key environment variable
load_dotenv()
api_key = os.getenv("NEWS_API_KEY")
print(api_key)
# Out:
# 1ee42792279e4bb38c96b682f9029b47

# %%
# Create a newsapi client
from newsapi import NewsApiClient
newsapi = NewsApiClient(api_key)

# %%
search_term= input("What Search Term?")
# Out:
# What Search Term? help

# %%
# Fetch the news articles
btc_headlines = newsapi.get_everything(
    search_term,
    language="en",
    page_size=100,
    sort_by="relevancy"
)
btc_headlines
# Out:
# {'status': 'ok',
#  'totalResults': 213636,
#  'articles': [{'source': {'id': 'engadget', 'name': 'Engadget'},
#    'author': 'Karissa Bell',
#    'title': 'Meta withdraws Oversight Board request for help with Ukraine policies',
#    'description': 'Meta has withdrawn\r\n a request it made to its oversight Board seeking guidance on shaping its content moderation policies amid Russia’s invasion of Ukraine. The company had originally asked the Oversight Board for a policy advisory opinion (PAO) in March, fol…',
#    'url': 'https://www.engadget.com/meta-withdraws-oversight-board-request-for-help-with-ukraine-policies-193638529.html',
#    'urlToImage': 'https://s.yimg.com/os/creatr-uploaded-images/2021-01/4e4406f0-616e-11eb-bedf-b2adf9310de2',
#    'publishedAt': '2022-05-11T19:36:38Z',
#    'content': 'Meta has withdrawn\r\n a request it made to its oversight Board seeking guidance on shaping its content moderation policies amid Russias invasion of Ukraine. The company had originally asked the Oversi… [+1944 chars]'},
#   {'source': {'id': None, 'name': 'Lifehacker.com'},
#    'author': 'Jonathan van Halem',
#    'title': 'These Tricks Will Help You Relieve Yourself of Your Bathroom ‘Stage Fright’',
#    'description': 'If you have a tough time taking care of your business in a public restroom, you’re not alone. According to the International Paruresis Association, an estimated twenty-one million Americans suffer from paruresis, or what is colloquially known as “shy bladder …',
#    'url': 'https://lifehacker.com/these-tricks-will-help-you-relieve-yourself-of-your-bat-1848892835',
#    'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/f040550f5c249b319bb756db675b9645.jpg',
#    'publishedAt': '2022-05-09T13:00:00Z',
#    'content': 'If you have a tough time taking care of your business in a public restroom, youre not alone. According to the International Paruresis Association, an estimated twenty-one million Americans suffer fro… [+2938 chars]'},
#   {'source': {'id': None, 'name': 'Lifehacker.com'},
#    'author': 'Jake Peterson',
#    'title': 'How to Help Convince Tech Companies to Make a Smaller Smartphone',
#    'description': 'A long time ago, smartphones were small. Like, really small. It used to be a given that such a device should fit snugly in the hand, so you could do everything you need to with it using only your thumb. They certainly don’t make ‘em like they used to.In 2022,…',
#    'url': 'https://lifehacker.com/how-to-help-convince-tech-companies-to-make-a-smaller-s-1848954626',
#    'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/9f6dab72e87451c4668b5563926bf7ec.jpg',
#    'publishedAt': '2022-05-20T19:30:00Z',
#    'content': 'A long time ago, smartphones were small. Like, really small. It used to be a given that such a device should fit snugly in the hand, so you could do everything you need to with it using only your thu… [+5130 chars]'},
#   {'source': {'id': 'wired', 'name': 'Wired'},
#    'author': 'Haley Sprankle',
#    'title': '9 Great Deals on Audio Tech, Projectors, and Coffee Gear',
#    'description': 'These discounts can help you make home your happy place.',
#    'url': 'https://www.wired.com/story/weekend-deals-5-14-2022/',
#    'urlToImage': 'https://media.wired.com/photos/627eba230bf49e8805b8af91/191:100/w_1280,c_limit/Beats-Flex-Headphones-Gear.jpg',
#    'publishedAt': '2022-05-14T11:00:00Z',
#    'content': 'Going outside is expensive. Well, not literally, but it does seem like every time I walk out my front door Im headed to another café or less-than-affordable activity. I by no means think cutting out … [+3709 chars]'},
#   {'source': {'id': 'wired', 'name': 'Wired'},
#    'author': 'Matt Simon',
#    'title': 'Give Fitbits (of Sorts) to the Trees',
#    'description': 'You can tell a lot about a tree by its sway, so scientists are outfitting them with accelerometers. That could help the West better manage its water.',
#    'url': 'https://www.wired.com/story/give-fitbits-of-sorts-to-the-trees/',
#    'urlToImage': 'https://media.wired.com/photos/626c027886b7addd3002e642/191:100/w_1280,c_limit/trees_aerial_fitbit_science_IMG_2726.jpg',
#    'publishedAt': '2022-05-02T11:00:00Z',
#    'content': 'You might look at a tree swaying in the wind and see botanical tranquilitya hypnotic back and forth of life interacting with air. Scientists appreciate that too, but they also see something else: dat… [+2934 chars]'},
#   {'source': {'id': 'wired', 'name': 'Wired'},
#    'author': 'Rachel Botsman',
#    'title': 'Tech Leaders Can Do More to Avoid Unintended Consequences',
#    'description': "It's difficult to predict the negative impacts of an idea or invention, but certain frameworks can help entrepreneurs \xa0see a little bit further.",
#    'url': 'https://www.wired.com/story/technology-unintended-consequences/',
#    'urlToImage': 'https://media.wired.com/photos/628c3639bcc5b49b113f4b09/191:100/w_1280,c_limit/tech%20consequences%20(0;00;08;11).jpg',
#    'publishedAt': '2022-05-24T12:00:00Z',
#    'content': 'In 1936, social scientist Robert Merton proposed a framework for understanding different types of unanticipated consequencesperverse results, unexpected drawbacks, and unforeseen benefits. Mertons ch… [+3189 chars]'},
#   {'source': {'id': None, 'name': 'New York Times'},
#    'author': 'Helen Ouyang, Jack D’Isidoro, Aaron Esposito, John Woo, Dan Powell and Brian St. Pierre',
#    'title': 'The Sunday Read: ‘Can Virtual Reality Help Ease Chronic Pain?’',
#    'description': 'V.R. treatments may provide relief similar to intravenous opioids — a tantalizing prospect for the millions of Americans living with chronic pain.',
#    'url': 'https://www.nytimes.com/2022/05/22/podcasts/the-daily/the-sunday-read-virtual-reality-and-chronic-pain.html',
#    'urlToImage': 'https://static01.nyt.com/images/2022/05/01/magazine/22daily-audm-1/01mag-vr-pain-facebookJumbo.jpg',
#    'publishedAt': '2022-05-22T10:00:10Z',
#    'content': 'There are a lot of ways to listen to The Daily. Heres how.\r\nWe want to hear from you. Tune in, and tell us what you think. Email us at thedaily@nytimes.com. Follow Michael Barbaro on Twitter: @mikieb… [+501 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Andrew J. Hawkins',
#    'title': 'Bollinger selects manufacturing supplier to help build its electric commercial vehicles',
#    'description': 'Bollinger has selected Roush as its contract manufacturer to help build its forthcoming lineup of electric commercial vehicles.',
#    'url': 'https://www.theverge.com/2022/5/9/23063629/bollinger-roush-contract-manufacture-ev-commercial',
#    'urlToImage': 'https://cdn.vox-cdn.com/thumbor/IZvf6ehLkIQuGnCg7G7yfej1Kk8=/0x94:4800x2607/fit-in/1200x630/cdn.vox-cdn.com/uploads/chorus_asset/file/21824794/Bollinger_Motors_DELIVER_E_Side.jpg',
#    'publishedAt': '2022-05-09T16:00:00Z',
#    'content': 'The struggling EV startup will work with Roush\r\nElectric vehicle startup Bollinger said it has selected its manufacturing supplier to build its forthcoming delivery van. The company will use Detroit … [+2265 chars]'},
#   {'source': {'id': 'wired', 'name': 'Wired'},
#    'author': 'Lisa Kanarek',
#    'title': 'How to Use Tech to Perform Acts of Kindness',
#    'description': 'Tech can get us down—but it can also empower us to help others. Here’s how to volunteer virtually, share your skills, or simply brighten someone’s day.',
#    'url': 'https://www.wired.com/story/how-to-use-tech-to-perform-acts-of-kindness/',
#    'urlToImage': 'https://media.wired.com/photos/627eec510c454f12d51426b7/191:100/w_1280,c_limit/Spread-Kindness-with-Tech-Gear-GettyImages-1333520740.jpg',
#    'publishedAt': '2022-05-14T11:00:00Z',
#    'content': 'The need to spread goodwill feels more vital than ever. After coping with a global pandemic for more than two years, followed by the horrific war in Ukraine, we could all use the boost that helping o… [+6133 chars]'},
#   {'source': {'id': 'bbc-news', 'name': 'BBC News'},
#    'author': 'https://www.facebook.com/bbcnews',
#    'title': "'Rise in Muslim families' seeking Ramadan food help",
#    'description': 'Some Muslims have been struggling to afford food to break their fasts amid the soaring cost of living.',
#    'url': 'https://www.bbc.co.uk/news/uk-61215836',
#    'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/8BAA/production/_124345753_arshiandfamily.jpg',
#    'publishedAt': '2022-04-29T23:20:25Z',
#    'content': "By Emb HashmiBBC News\r\nImage source, Family photo\r\nImage caption, Arshi Begum and her husband are struggling to manage due to the UK's soaring cost of living\r\nAs Ramadan, Islam's holy month of fastin… [+4731 chars]"},
#   {'source': {'id': None, 'name': 'Lifehacker.com'},
#    'author': 'Beth Skwarecki',
#    'title': "Anti-Allergy Face Wipes Aren't What You Think They Are",
#    'description': 'When I learned about the existence of Zyrtec face wipes, I was surprised and intrigued. I’ve used Zyrtec pills in the past to manage my spring pollen allergy (although they will never replace my first love, Claritin). Would wiping the stuff on my face help my…',
#    'url': 'https://lifehacker.com/anti-allergy-face-wipes-are-bullshit-sort-of-1848911194',
#    'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/7fb60ecbfe7c597038d8975513fcd5fb.jpg',
#    'publishedAt': '2022-05-11T20:30:00Z',
#    'content': 'When I learned about the existence of Zyrtec face wipes, I was surprised and intrigued. Ive used Zyrtec pills in the past to manage my spring pollen allergy (although they will never replace my first… [+2695 chars]'},
#   {'source': {'id': None, 'name': 'Lifehacker.com'},
#    'author': 'Meredith Dietz',
#    'title': "How to 'Steal' Free Routes From Strava",
#    'description': 'While looking into the best free route-building tools for cyclists and runners, I couldn’t help but lament the fate of\xa0Strava’s Route Builder. Long a favorite feature of the social app, the route builder gave runners and cyclists ability to create and customi…',
#    'url': 'https://lifehacker.com/how-to-steal-free-routes-from-strava-1848900774',
#    'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/0c32ca72adada189d26d87010b2d86c7.jpg',
#    'publishedAt': '2022-05-09T20:35:13Z',
#    'content': 'While looking into the best free route-building tools for cyclists and runners, I couldnt help but lament the fate of\xa0Stravas Route Builder. Long a favorite feature of the social app, the route build… [+2555 chars]'},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'Lauren Leffer',
#    'title': "Chicago Cops Can Use Fake Social Media Profiles to Spy On You, With the FBI's Help",
#    'description': 'Law enforcement agencies are finding new and\xa0flawed ways to try to arrest more people all the time. And police have been using posts on sites like Facebook and Instagram to track down and charge protestors suspected of property destruction for years. Now, new…',
#    'url': 'https://gizmodo.com/online-surveillance-ai-police-spying-chicago-1848955439',
#    'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/017730c936c9852e61e789def2c291ce.jpg',
#    'publishedAt': '2022-05-20T21:00:00Z',
#    'content': 'Law enforcement agencies are finding new and\xa0flawed ways to try to arrest more people all the time. And police have been using posts on sites like Facebook and Instagram to track down and charge prot… [+4177 chars]'},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'Andrew Liszewski',
#    'title': "Smart Screws That Can Detect When They're Loose Could Help Save America's Bridges",
#    'description': 'Working to reduce the need for regular inspections of large structures, researchers from the Fraunhofer Cluster of Excellence Cognitive Internet Technologies CCIT have created a smart self-powered screw that leverages IoT tricks to automatically send out aler…',
#    'url': 'https://gizmodo.com/researchers-invent-smart-screws-that-detect-when-loose-1848869729',
#    'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/e0f2f3e93aae0ebd32f72a9859f7a0e2.jpg',
#    'publishedAt': '2022-05-02T21:10:00Z',
#    'content': 'Working to reduce the need for regular inspections of large structures, researchers from the Fraunhofer Cluster of Excellence Cognitive Internet Technologies CCIT have created a smart self-powered sc… [+3089 chars]'},
#   {'source': {'id': None, 'name': 'New York Times'},
#    'author': 'Ashley Southall',
#    'title': '4 Who Helped Catch Subway Attack Suspect Now Need Help Themselves',
#    'description': 'They aided investigators after the worst subway attack in decades. Will that be enough to persuade immigration authorities to give them visas or asylum?',
#    'url': 'https://www.nytimes.com/2022/05/14/nyregion/subway-shooting-immigration-protection.html',
#    'urlToImage': 'https://static01.nyt.com/images/2022/05/12/nyregion/00ny-immig/00ny-immig-facebookJumbo.jpg',
#    'publishedAt': '2022-05-14T09:00:19Z',
#    'content': 'Last month, Ms. Flores, 37, dropped her younger daughter at school and boarded an N train at 59th Street in Brooklyn, headed to work on Manhattans Upper West Side. She chose the second car because sh… [+1448 chars]'},
#   {'source': {'id': None, 'name': 'New York Times'},
#    'author': 'J. David Goodman, Edgar Sandoval, Karen Zraick and Rick Rojas',
#    'title': 'Children called for help from inside classrooms in Uvalde. The police waited.',
#    'description': 'A new timeline from the state police raised questions about whether lives could have been saved with swift action.',
#    'url': 'https://www.nytimes.com/2022/05/27/us/children-called-for-help-from-inside-classrooms-in-uvalde-the-police-waited.html',
#    'urlToImage': 'https://static01.nyt.com/images/2022/06/27/world/27uvalde-shooting-pinned-item/27uvalde-shooting-pinned-item-facebookJumbo.jpg',
#    'publishedAt': '2022-05-28T09:56:58Z',
#    'content': 'Jasmine Carrillo, 29, was working in the cafeteria with about 40 second-graders and two teachers when the attack began. The lights dimmed part of a schoolwide lockdown that had gone into effect.\r\nOnc… [+1848 chars]'},
#   {'source': {'id': None, 'name': 'New York Times'},
#    'author': 'Kenneth P. Vogel and Michael S. Schmidt',
#    'title': 'Hunter Biden Turns to Hollywood Lawyer for Financial Help and Counsel',
#    'description': 'Kevin Morris, known for brokering big entertainment deals, has helped President Biden’s son navigate his legal troubles and scrutiny from the right. Some of the White House’s allies are concerned.',
#    'url': 'https://www.nytimes.com/2022/05/10/us/politics/hunter-biden-kevin-morris-lawyer.html',
#    'urlToImage': 'https://static01.nyt.com/images/2022/05/10/us/politics/10dc-hunter3/10dc-hunter3-facebookJumbo.jpg',
#    'publishedAt': '2022-05-10T20:57:07Z',
#    'content': 'Mr. Biden and Mr. Morris both lived in Los Angeles and became close, with Mr. Morris assisting as Mr. Biden worked to finish a memoir. It detailed his struggles with addiction and loss and credited h… [+1687 chars]'},
#   {'source': {'id': 'engadget', 'name': 'Engadget'},
#    'author': 'Kris Holt',
#    'title': 'Google adds some useful features for finding flights and hotels',
#    'description': 'The summer is fast approaching and many people are perhaps gearing up for their first big vacation in a few years. To help them plan, Google\r\n is rolling out some handy travel updates\r\n. These include upgraded flight price tracking and ways to find and save h…',
#    'url': 'https://www.engadget.com/google-travel-updates-flights-hotels-135911872.html',
#    'urlToImage': 'https://s.yimg.com/os/creatr-uploaded-images/2021-01/57e28010-601a-11eb-beef-5866772b42be',
#    'publishedAt': '2022-05-02T13:59:11Z',
#    'content': 'The summer is fast approaching and many people are perhaps gearing up for their first big vacation in a few years. To help them plan, Google\r\n is rolling out some handy travel updates\r\n. These includ… [+1691 chars]'},
#   {'source': {'id': 'bbc-news', 'name': 'BBC News'},
#    'author': 'https://www.facebook.com/bbcnews',
#    'title': 'Ukraine war: Zelensky plea as Russians seek Mariupol endgame',
#    'description': "The Ukrainian president appeals for fresh UN help as Russians reportedly enter the city's last holdout.",
#    'url': 'https://www.bbc.co.uk/news/world-europe-61327638',
#    'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/139E0/production/_124425308_hi075741324.jpg',
#    'publishedAt': '2022-05-04T22:12:55Z',
#    'content': 'Ukrainian officials say Russian forces have launched an all-out assault on the Azovstal steelworks, the last Ukrainian holdout in the city of Mariupol. \r\nUkrainian forces inside the plant have been f… [+4151 chars]'},
#   {'source': {'id': 'bbc-news', 'name': 'BBC News'},
#    'author': 'https://www.facebook.com/bbcnews',
#    'title': 'Uvalde shooting: Texas police change key details as criticism mounts',
#    'description': "'If I thought it would help, I would apologise,' official says amid heated press conference.",
#    'url': 'https://www.bbc.co.uk/news/world-us-canada-61613177',
#    'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/111E2/production/_124941107_gettyimages-1240923427.jpg',
#    'publishedAt': '2022-05-27T16:57:51Z',
#    'content': 'Media caption, \'I just want my baby home\' - relatives of children speak of their heartbreak\r\nPolice made the "wrong decision" by failing to storm a classroom in Robb Elementary School as a gunman kil… [+1791 chars]'},
#   {'source': {'id': None, 'name': 'Seths.blog'},
#    'author': 'Seth Godin',
#    'title': 'The ones who didn’t help',
#    'description': 'If 2% of a population takes coordinated action, it makes a difference. If 5% do, it can change everything. This simple math also means that most people rarely do anything. Perhaps they don’t care. Perhaps they’re afraid to speak up and commit. And perhaps it’…',
#    'url': 'https://seths.blog/2022/05/the-ones-who-didnt-help/',
#    'urlToImage': 'https://149521506.v2.pressablecdn.com/wp-content/uploads/2018/06/seth_godin_ogimages_v02_18061317.jpg',
#    'publishedAt': '2022-05-09T08:26:00Z',
#    'content': 'If 2% of a population takes coordinated action, it makes a difference. If 5% do, it can change everything.\r\nThis simple math also means that most people rarely do anything. Perhaps they don’t care. P… [+628 chars]'},
#   {'source': {'id': 'engadget', 'name': 'Engadget'},
#    'author': 'Jon Fingas',
#    'title': 'You can practice for a job interview with Google AI',
#    'description': 'Never mind reading generic guides or practicing with friends — Google is betting that algorithms can get you ready for a job interview. The company has launched an Interview Warmup tool that uses AI to help you prepare for interviews across various roles. The…',
#    'url': 'https://www.engadget.com/google-ai-job-interview-warmup-141504831.html',
#    'urlToImage': 'https://s.yimg.com/os/creatr-images/2019-10/31f9abc0-e9b1-11e9-bbec-7dffe7a615de',
#    'publishedAt': '2022-05-17T14:15:04Z',
#    'content': 'Never mind reading generic guides or practicing with friends Google is betting that algorithms can get you ready for a job interview. The company has launched an Interview Warmup tool that uses AI to… [+886 chars]'},
#   {'source': {'id': 'engadget', 'name': 'Engadget'},
#    'author': 'Igor Bonifacic',
#    'title': '‘Big Hero 6’ sequel ‘Baymax!’ hits Disney+ on June 29th',
#    'description': 'Baymax!, the Disney+ sequel to 2014’s Big Hero 6, will debut on June 29th. Disney shared the release date on Friday, alongside a new trailer showing the loveable healthcare robot from the film attempting to help the citizens of San Fransokyo.\xa0\r\n“In each of ou…',
#    'url': 'https://www.engadget.com/baymax-disney-plus-june-29th-174354828.html',
#    'urlToImage': 'https://s.yimg.com/os/creatr-uploaded-images/2022-05/ba56c580-d92c-11ec-bff7-45aa6fb43afe',
#    'publishedAt': '2022-05-21T17:43:54Z',
#    'content': 'Baymax!, the Disney+ sequel to 2014s Big Hero 6, will debut on June 29th. Disney shared the release date on Friday, alongside a new trailer showing the loveable healthcare robot from the film attempt… [+626 chars]'},
#   {'source': {'id': None, 'name': 'New York Times'},
#    'author': 'Andy Cochrane and Rachel Woolf',
#    'title': 'At the Top of His Sport, Joseph Gray is Focused the Next Generation of Black Athletes',
#    'description': 'Joseph Gray is the most decorated American mountain runner. As the lone Black runner at the top, he wants to help diversify the field.',
#    'url': 'https://www.nytimes.com/2022/05/14/sports/joseph-gray-mountain-running.html',
#    'urlToImage': 'https://static01.nyt.com/images/2022/05/12/sports/00mountain-running-gray-top/00mountain-running-gray-top-facebookJumbo.jpg',
#    'publishedAt': '2022-05-15T16:11:34Z',
#    'content': 'I knew it wouldnt be easy, but I couldnt stay quiet. It started with conversations with close friends, recognizing we all were experiencing the same prejudice. Winning races wasnt enough to change th… [+1449 chars]'},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'Kevin Hurler and Shoshana Wodinsky',
#    'title': 'Twitter’s New Privacy Policy Is a Video Game That Sucks',
#    'description': 'Twitter unveiled a game designed to help users get a handle on the platform’s privacy policies on Tuesday. It’s both cheery and deeply confusing.Read more...',
#    'url': 'https://gizmodo.com/twitter-privacy-policy-video-game-data-dash-1848912387',
#    'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/c864766482628ec5415d7c914dbaeec5.png',
#    'publishedAt': '2022-05-11T21:17:00Z',
#    'content': 'Twitter unveiled a game designed to help users get a handle on the platforms privacy policies on Tuesday. Its both cheery and deeply confusing.\r\nTwitter Data Dash tells the story of you and your dog … [+5150 chars]'},
#   {'source': {'id': None, 'name': 'New York Times'},
#    'author': 'Emily Cochrane',
#    'title': 'House Democrats Release $28 Million Aid Bill to Address Formula Shortage',
#    'description': 'The money is intended to help the Food and Drug Administration increase its staff and prepare for future shortages of infant formula.',
#    'url': 'https://www.nytimes.com/2022/05/17/us/politics/baby-formula-shortage-house-bill.html',
#    'urlToImage': 'https://static01.nyt.com/images/2022/05/17/us/politics/17dc-formula/17dc-formula-facebookJumbo.jpg',
#    'publishedAt': '2022-05-17T17:58:11Z',
#    'content': 'Republicans, however, quickly said they would oppose the measure, criticizing it as ineffective and noting that it contained no instructions on how to spend the money.\r\nThis bill is yet another case … [+1062 chars]'},
#   {'source': {'id': None, 'name': 'New York Times'},
#    'author': 'Margaret Roach',
#    'title': 'Why Trillium Have Become the Poster Child for Endangered Native Plants',
#    'description': 'According to a recent report, many of these ‘charismatic’ wildflowers are threatened with extinction. Here’s what you can do to help.',
#    'url': 'https://www.nytimes.com/2022/05/25/realestate/trillium-endangered-plants.html',
#    'urlToImage': 'https://static01.nyt.com/images/2022/05/24/realestate/25garden01/oakImage-1653403015451-facebookJumbo.jpg',
#    'publishedAt': '2022-05-25T09:00:35Z',
#    'content': 'I have many generations of ants to thank, apparently, as they are participants in a form of plant-animal mutualism called myrmecochory. Attracted by an elaiosome, a lipid-rich packet attached to the … [+1391 chars]'},
#   {'source': {'id': None, 'name': 'New York Times'},
#    'author': 'Lara Jakes',
#    'title': 'In Ukraine War, a Long Journey Begins in Prosecuting Rape',
#    'description': 'U.N. officials and human rights investigators are rushing more resources to authorities in Ukraine to help prosecute sex crimes.',
#    'url': 'https://www.nytimes.com/2022/04/29/us/politics/ukraine-rape-war-crimes.html',
#    'urlToImage': 'https://static01.nyt.com/images/2022/04/28/us/politics/00dc-ukraine-sexcrimes/merlin_205903455_d4c3d3d7-4a80-4d39-84ad-689d1f540602-facebookJumbo.jpg',
#    'publishedAt': '2022-04-29T13:05:33Z',
#    'content': 'She is appealing to other countries that are party to the international court to consider opening their own prosecutions into allegations of Russias sex crimes by claiming universal jurisdiction the … [+2120 chars]'},
#   {'source': {'id': 'bbc-news', 'name': 'BBC News'},
#    'author': 'https://www.facebook.com/bbcnews',
#    'title': 'Ukraine bid to join EU will take decades says Macron',
#    'description': 'The French leader suggests other ways the EU can help Ukraine, other than fast tracking its membership.',
#    'url': 'https://www.bbc.co.uk/news/world-europe-61383632',
#    'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/8B83/production/_124651753_tv075886691.jpg',
#    'publishedAt': '2022-05-09T14:56:08Z',
#    'content': 'Image caption, The French president suggested Ukraine could join a "parallel European community" to allow non-EU members to still benefit from Europe\'s security structures\r\nIt will take decades for U… [+1894 chars]'},
#   {'source': {'id': 'bbc-news', 'name': 'BBC News'},
#    'author': 'https://www.facebook.com/bbcnews',
#    'title': "How can Ukraine's food be got out?",
#    'description': "Ukraine has crops that could help lower food prices, but there's no easy way of getting them.",
#    'url': 'https://www.bbc.co.uk/news/world-europe-61583492',
#    'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/11E19/production/_124914237_53ba5e49-e90e-4617-9bfa-04c9835f961f.jpg',
#    'publishedAt': '2022-05-25T23:52:58Z',
#    'content': 'By Stephanie HegartyPopulation correspondent \r\nImage source, Nadiya Stetsiuk\r\nImage caption, Nadiya Stetsiuk and her son cannot continue without funds from the sale of crops\r\nUkrainian farmers have 2… [+7843 chars]'},
#   {'source': {'id': 'bbc-news', 'name': 'BBC News'},
#    'author': None,
#    'title': "Acid attack survivors in Mexico: 'Justice is not enough'",
#    'description': 'Carmen Sanchez launched her foundation in Mexico to help survivors of attacks rebuild their lives.',
#    'url': 'https://www.bbc.co.uk/news/av/world-latin-america-61346864',
#    'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/17856/production/_124624369_p0c5b99s.jpg',
#    'publishedAt': '2022-05-07T23:11:30Z',
#    'content': 'After Carmen Sanchez left her abusive ex-partner, he attacked her with acid, leaving her severely scarred. \r\nLast year, she launched her foundation in Mexico to help survivors of attacks to rebuild t… [+425 chars]'},
#   {'source': {'id': 'cnn', 'name': 'CNN'},
#    'author': 'Allison Morrow, CNN Business',
#    'title': 'These companies will help staff in red states bypass abortion bans',
#    'description': "Millions of women in more than 25 states face an abortion ban if the Supreme Court overturns Roe v. Wade, the landmark 1973 decision that legalized the procedure nationwide. For many of those women, employers' benefit packages may be the only way they can soo…",
#    'url': 'https://www.cnn.com/2022/05/03/business/amazon-abortion-costs/index.html',
#    'urlToImage': 'https://cdn.cnn.com/cnnnext/dam/assets/220503101454-01-amazon-packages-file-super-tease.jpg',
#    'publishedAt': '2022-05-03T16:03:03Z',
#    'content': 'New York (CNN Business)Millions of women in more than 25 states face an abortion ban if the Supreme Court overturns Roe v. Wade, the landmark 1973 decision that legalized the procedure nationwide. Fo… [+5955 chars]'},
#   {'source': {'id': 'the-verge', 'name': 'The Verge'},
#    'author': 'Cameron Faulkner',
#    'title': 'The Verge’s 2022 Father’s Day Gift Guide',
#    'description': 'For this year’s Father’s Day, why not pick up a thoughtful gift ahead of time with the help of The Verge? Whether the dad in your life enjoys working with tools, geeking out over tech, or relaxing with a book, we’ve got some ideas for you.',
#    'url': 'https://www.theverge.com/23069006/fathers-day-gift-ideas-2022-best-dad-unique-tech-gadgets-tools',
#    'urlToImage': 'https://cdn.vox-cdn.com/thumbor/FUv4YcyfENk1ycs_lH8BAqmK6E0=/0x98:2050x1171/fit-in/1200x630/cdn.vox-cdn.com/uploads/chorus_asset/file/23577098/VRG_ILLO_5233_FD_GG_2022_search.jpg',
#    'publishedAt': '2022-05-23T14:00:00Z',
#    'content': "The Busy Bistro Magic Puzzle\r\nGifting a puzzle might sound a bit tame, but it can be an exciting one if it's as uniquely detailed as The Busy Bistro Magic Puzzle. It'll be a gift that puzzle lovers a… [+11354 chars]"},
#   {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'author': 'insider@insider.com (Sponsor Post)',
#    'title': 'New help for striving communities',
#    'description': 'With vulnerable communities facing more challenges than ever, it is now incumbent on the private sector to offer sustainable financing solutions.',
#    'url': 'https://www.businessinsider.com/sc/in-struggling-communities-new-forms-of-help-are-now-necessary',
#    'urlToImage': 'https://i.insider.com/624c659116e2c4001966706a?width=1200&format=jpeg',
#    'publishedAt': '2022-05-09T15:40:00Z',
#    'content': 'Illustration Credit: Kingsley Nebechi\r\nAs the private sector innovates aid and financing, seeking holistic solutions to neighborhood challenges is the cornerstone of the approach\r\nCommunities across … [+6047 chars]'},
#   {'source': {'id': None, 'name': 'New York Times'},
#    'author': 'The New York Times',
#    'title': 'Zelensky Says Military Aid Could Free Up Exports, Easing Food Prices',
#    'description': 'President Volodymyr Zelensky said wresting control of ports from Russia could help ease global price pressures from the war. President Biden signed one of the largest aid packages in decades on Saturday.',
#    'url': 'https://www.nytimes.com/live/2022/05/22/world/russia-ukraine-war',
#    'urlToImage': 'https://static01.nyt.com/images/2022/05/22/world/22ukraine-blog-promo-1am/22ukraine-blog-promo-1am-facebookJumbo.jpg',
#    'publishedAt': '2022-05-22T05:19:55Z',
#    'content': 'President Biden on Saturday signed a new $40 billion package of military and humanitarian aid for Ukraine as the country braced for a drawn-out war of attrition in its eastern regions, vowing that it… [+9230 chars]'},
#   {'source': {'id': None, 'name': 'New York Times'},
#    'author': 'Glenn Thrush',
#    'title': 'At N.R.A. Convention, the Blame Is on ‘Evil,’ Not Guns',
#    'description': 'At least two children called 911 for help from inside classrooms while the police waited. Gov. Greg Abbott of Texas said he had been ‘misled’ about the events and the police response and was ‘absolutely livid.’',
#    'url': 'https://www.nytimes.com/live/2022/05/28/us/texas-school-shooting',
#    'urlToImage': 'https://static01.nyt.com/images/2022/05/27/lens/27dc-nra-Trump-2/merlin_207643686_cb8bb1de-f0ef-4636-a258-a62687fc2989-facebookJumbo.jpg',
#    'publishedAt': '2022-05-28T01:19:27Z',
#    'content': 'UVALDE, Texas Furtively, speaking in a whisper, a fourth-grade girl dialed the police. Around her, in Room 112 at Robb Elementary School, were the motionless bodies of her classmates and scores of sp… [+10817 chars]'},
#   {'source': {'id': None, 'name': 'New York Times'},
#    'author': 'Chelsia Rose Marcius and Nate Schweber',
#    'title': '‘We Need All Eyes on This’: Police Officers Hunt for Subway Gunman',
#    'description': 'The police released images of the suspect who fatally shot a 48-year-old man on the Q train on Sunday, and they asked for help in locating the gunman.',
#    'url': 'https://www.nytimes.com/2022/05/23/nyregion/nyc-subway-shooting.html',
#    'urlToImage': 'https://static01.nyt.com/images/2022/05/23/nyregion/23nysubway1/merlin_207345684_4c190a19-3957-4804-a408-b5622a42e4c1-facebookJumbo.jpg',
#    'publishedAt': '2022-05-23T15:49:20Z',
#    'content': 'The attack is the latest in a string of violent episodes in city subways this year, including a shooting last month that left at least 23 people injured, as well as the death of a woman in Times Squa… [+1466 chars]'},
#   {'source': {'id': None, 'name': 'New York Times'},
#    'author': 'Annie Karni',
#    'title': 'Republicans Block Bill That Would Protect Abortion Access',
#    'description': 'Republicans used a filibuster to thwart efforts to enshrine abortion rights in federal law, although Democrats hoped the high-profile failure would help them at the polls in November.',
#    'url': 'https://www.nytimes.com/2022/05/11/us/abortion-bill-blocked-senate.html',
#    'urlToImage': 'https://static01.nyt.com/images/2022/05/11/us/politics/11dc-abortion/11dc-abortion-facebookJumbo.jpg',
#    'publishedAt': '2022-05-11T21:29:59Z',
#    'content': 'The legislation, he said, goes way, way beyond codifying the status quo; it would roll back many existing laws.\r\nCard 1 of 4What is Roe v. Wade?Roe v. Wade is a landmark Supreme court decision that l… [+2511 chars]'},
#   {'source': {'id': None, 'name': 'New York Times'},
#    'author': 'Reid J. Epstein',
#    'title': 'Wisconsin Democrats Sue G.O.P. Fake Electors Over 2020 Scheme',
#    'description': 'In the first lawsuit of its kind, two real Electoral College delegates from 2020 are seeking damages from 10 fake ones who tried to help Donald Trump overturn his defeat in the state.',
#    'url': 'https://www.nytimes.com/2022/05/17/us/politics/wisconsin-fake-electors.html',
#    'urlToImage': 'https://static01.nyt.com/images/2022/05/17/multimedia/17pol-wisconsin-electors-photo/17pol-wisconsin-electors-photo-facebookJumbo.jpg',
#    'publishedAt': '2022-05-17T18:23:53Z',
#    'content': 'There have been no criminal charges filed against any member of the seven slates of fake Republican electors who sought to overturn the 2020 presidential election results. Republicans in Arizona, Geo… [+1228 chars]'},
#   {'source': {'id': None, 'name': 'New York Times'},
#    'author': 'Andrew Higgins and Benjamin Novak',
#    'title': 'Hooked on Cheap Oil, Hungary Resists an Embargo on Russia',
#    'description': 'Prime Minister Viktor Orban has promised voters to keep energy prices low. The dividends from taking Russian fuel also help fund the policies that have made Hungary a beacon for right-wing groups.',
#    'url': 'https://www.nytimes.com/2022/05/19/world/europe/hungary-russia-oil.html',
#    'urlToImage': 'https://static01.nyt.com/images/2022/05/19/world/xxhungary-russia01/merlin_206508993_087277a6-b12a-432a-917e-5b1054ad7ba0-facebookJumbo.jpg',
#    'publishedAt': '2022-05-19T16:00:10Z',
#    'content': 'Reporting a big jump in profits, MOL warned in its annual financial report this spring that it was exposed to Russia through a minority stake in a small Russian oil company, BaiTex, and by the physic… [+1643 chars]'},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'Kevin Hurler',
#    'title': "A New Docuseries Based on Gizmodo's The Gateway Premieres Tonight",
#    'description': 'The Deep End is an upcoming docuseries—based on the Gizmodo podcast The Gateway—that follows Teal Swan, a self-proclaimed spiritual leader, her tantalizing self-help empire, and those who follow it devoutly.Read more...',
#    'url': 'https://gizmodo.com/the-deep-end-documentary-adapts-gizmodos-the-gateway-1848942953',
#    'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/de12002573de51661abd876a90640d32.jpg',
#    'publishedAt': '2022-05-18T18:55:00Z',
#    'content': 'The Deep End is an upcoming docuseriesbased on the Gizmodo podcastThe Gatewaythat follows Teal Swan, a self-proclaimed spiritual leader, her tantalizing self-help empire, and those who follow it devo… [+1598 chars]'},
#   {'source': {'id': None, 'name': 'New York Times'},
#    'author': 'Alan Feuer',
#    'title': 'Oath Keepers Leader Sought to Ask Trump to Unleash His Militia',
#    'description': 'A dramatic account of how the militia leader, Stewart Rhodes, tried to reach Donald J. Trump on Jan. 6 with a message that the group could help keep him in power was revealed in federal court.',
#    'url': 'https://www.nytimes.com/2022/05/04/us/politics/oath-keepers-jan-6-riot.html',
#    'urlToImage': 'https://static01.nyt.com/images/2022/05/04/us/politics/04DC-Investigate/merlin_182227173_afda4f53-dc9f-4e1a-912a-149b3114103e-facebookJumbo.jpg',
#    'publishedAt': '2022-05-04T22:51:55Z',
#    'content': 'Rigged, he wrote. And then, Im ready to go coyote hunting.\r\nOn Dec. 14, 2020 the day that a majority of electors cast their votes for Mr. Biden in the Electoral College Mr. Wilson saw an article post… [+1984 chars]'},
#   {'source': {'id': 'cnn', 'name': 'CNN'},
#    'author': None,
#    'title': "Home buyers aren't using a realtor. Here's what they're doing instead",
#    'description': 'According to the National Association of Realtors 1 in 7 buyers are not using a realtor to help with a home purchase, which may present some challenges.',
#    'url': 'https://www.cnn.com/videos/business/2022/05/03/buyers-not-using-realtors-inflation-hln-mxp-vpx.hln',
#    'urlToImage': 'https://cdn.cnn.com/cnnnext/dam/assets/220412130613-us-home-buying-real-estate-super-tease.jpg',
#    'publishedAt': '2022-05-03T18:15:45Z',
#    'content': 'Morning Express with Robin Meade'},
#   {'source': {'id': 'ars-technica', 'name': 'Ars Technica'},
#    'author': 'Doug Johnson',
#    'title': 'Citizen scientists help discover more than 1,000 new asteroids',
#    'description': 'Crowd-sourced project unearths more than 1,000 asteroids in 37,000 Hubble images.',
#    'url': 'https://arstechnica.com/science/2022/05/citizen-scientists-help-discover-more-than-1000-new-asteroids/',
#    'urlToImage': 'https://cdn.arstechnica.net/wp-content/uploads/2022/05/heic2207a-760x380.jpg',
#    'publishedAt': '2022-05-16T17:24:55Z',
#    'content': 'Enlarge/ This mosaic consists of 16 different data sets from the NASA/ESA Hubble Space Telescope that were studied as part of the Asteroid Hunter citizen science project. Each of these data sets was … [+3330 chars]'},
#   {'source': {'id': None, 'name': 'New York Times'},
#    'author': 'Helene Cooper, Eric Schmitt and Julian E. Barnes',
#    'title': 'U.S. Intelligence Helped Ukraine Strike Russian Flagship, Officials Say',
#    'description': 'The help that sank the Moskva, the most significant loss by any navy in 40 years, is part of an administration effort providing real-time battlefield intelligence to Ukraine.',
#    'url': 'https://www.nytimes.com/2022/05/05/us/politics/moskva-russia-ship-ukraine-us.html',
#    'urlToImage': 'https://static01.nyt.com/images/2022/05/02/us/politics/02dc-moskva-1/merlin_205512990_6ffa49a7-4e07-4612-a274-56bcc9532185-facebookJumbo.jpg',
#    'publishedAt': '2022-05-05T23:01:37Z',
#    'content': 'For decades, the Moskva, a potent embodiment of Russian naval power in the Black Sea, bristled with missiles and loomed ominously on the horizon, inspiring awe in those who saw it.\r\nBut American Navy… [+1243 chars]'},
#   {'source': {'id': None, 'name': 'New York Times'},
#    'author': 'Blake Hounshell',
#    'title': 'Fox News Hosts Splinter as Chaotic Pennsylvania Primaries Heat Up',
#    'description': 'The rise of Kathy Barnette in the state’s G.O.P. Senate race has divided the network’s stars, with some backing her and others going on the attack to help a rival, Dr. Mehmet Oz.',
#    'url': 'https://www.nytimes.com/2022/05/13/us/politics/fox-news-barnette-oz-pennsylvania.html',
#    'urlToImage': 'https://static01.nyt.com/images/2022/05/13/multimedia/13onpolitics-barnette/13onpolitics-barnette-facebookJumbo.jpg',
#    'publishedAt': '2022-05-13T23:46:35Z',
#    'content': 'Democrats have giddily circulated their own research indicating that Barnette is leading the field in the Senate race by about 10 percentage points, but that survey was conducted before Trump issued … [+1718 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Campari plans new bars to help whet aperitif appetites - Reuters.com',
#    'description': 'Campari plans to open several flagship bars for its best-selling spirits in Europe and beyond to help tap into a taste for the Italian aperitif culture, its chief executive said.',
#    'url': 'https://www.reuters.com/business/retail-consumer/campari-plans-new-bars-help-whet-aperitif-appetites-2022-05-12/',
#    'urlToImage': 'https://www.reuters.com/resizer/F8B4TGEsYp2LXD-wWSNN_P2u8Tg=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/6JLVH3WAYFO4BBNRLMUKOBXWNY.jpg',
#    'publishedAt': '2022-05-12T11:47:00Z',
#    'content': 'MILAN, May 12 (Reuters) - Campari plans to open several flagship bars for its best-selling spirits in Europe and beyond to help tap into a taste for the Italian aperitif culture, its chief executive … [+2505 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Editorial',
#    'title': 'Breast milk banks help meet desperate need - Reuters',
#    'description': '05/27 The Mothers’ Milk Bank of the Western Great Lakes is seeing a sharp increase in demand for breast milk amid the nationwide baby formula shortage.',
#    'url': 'https://www.reuters.com/video/watch/idsPmY?now=true',
#    'urlToImage': 'https://ajo.prod.reuters.tv/api/v2/img/629160b3e4b09631b0e4910a-1653694643036?location=LANDSCAPE',
#    'publishedAt': '2022-05-28T01:07:30Z',
#    'content': 'Posted \r\n05/27 The Mothers Milk Bank of the Western Great Lakes is seeing a sharp increase in demand for breast milk amid the nationwide baby formula shortage.'},
#   {'source': {'id': None, 'name': 'Blog.google'},
#    'author': 'Richard HoldenVP of Travel Products',
#    'title': 'Plan your summer travel, with help from Google',
#    'description': 'Summer is fast approaching in most parts of the world, and there’s a familiar travel planning buzz in the air. Whether you have a destination in mind or are just dreaming about an escape, Google has tools to help you get inspired and research your options so …',
#    'url': 'https://blog.google/products/travel/plan-your-summer-travel-with-help-from-google/',
#    'urlToImage': 'https://storage.googleapis.com/gweb-uniblog-publish-prod/images/Hero_Google-Flight-Tracking_ehOFx8k.max-1300x1300.png',
#    'publishedAt': '2022-05-02T13:00:00Z',
#    'content': 'Track flight prices for any dates\r\nOn Google Flights, you can track prices for specific dates between two cities. Just search for your destination, toggle to opt-in, and well email you if prices drop… [+365 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'French federation appoints psychologists to help local players - Reuters.com',
#    'description': 'The French tennis federation (FFT) has appointed a team of psychologists to help the local players amid a long dry spell in Grand Slams.',
#    'url': 'https://www.reuters.com/lifestyle/sports/french-federation-appoints-psychologists-help-local-players-2022-05-24/',
#    'urlToImage': 'https://www.reuters.com/resizer/xQWO4mJyC8FRu7S4ELswuJicBKA=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/TCTFZ6B42NI6TJJSGR35DZ5D5Y.jpg',
#    'publishedAt': '2022-05-24T14:23:00Z',
#    'content': 'PARIS, May 24 (Reuters) - The French tennis federation (FFT) has appointed a team of psychologists to help the local players amid a long dry spell in Grand Slams.\r\nThe team is led by Francisca Dauzet… [+1514 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Star architect Foster to help plan Ukraine reconstruction - Reuters',
#    'description': "Renowned British architect Norman Foster will help plan Ukraine's reconstruction from the devastation caused by Russia's invasion, officials said on Friday while outlining the work of a United Nations task force coordinating the project.",
#    'url': 'https://www.reuters.com/world/europe/star-architect-foster-help-plan-ukraine-reconstruction-2022-05-06/',
#    'urlToImage': 'https://www.reuters.com/resizer/GX7OEGe_a-81YRoeyaNKftJ9Acc=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/KRM64KDU5VLOFMFQXGQS3TIPY4.jpg',
#    'publishedAt': '2022-05-06T12:31:00Z',
#    'content': "GENEVA, May 6 (Reuters) - Renowned British architect Norman Foster will help plan Ukraine's reconstruction from the devastation caused by Russia's invasion, officials said on Friday while outlining t… [+1632 chars]"},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Poland to propose new help for savers, says PM - Reuters',
#    'description': 'Poland will propose new help for savers in the coming days, the Polish prime minister said on Tuesday, without giving further details, as he criticised banks for not raising rates on deposits.',
#    'url': 'https://www.reuters.com/world/europe/poland-propose-new-help-savers-says-pm-2022-05-10/',
#    'urlToImage': 'https://www.reuters.com/resizer/Or8d_VBop8155wi2qmdAWoHoSfA=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/OJBE2HAOWVITZLC36HRP3MM24E.jpg',
#    'publishedAt': '2022-05-10T11:45:00Z',
#    'content': 'WARSAW, May 10 (Reuters) - Poland will propose new help for savers in the coming days, the Polish prime minister said on Tuesday, without giving further details, as he criticised banks for not raisin… [+487 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': "Breakingviews - Ukraine's spare energy can help itself and Europe - Reuters.com",
#    'description': 'Ukraine has an in-built weapon against the destruction wrought by conflict. With 55 gigawatts (GW) of installed power capacity, the war-torn nation can produce more electricity than it currently needs. That presents an opportunity for both Kyiv and the energy…',
#    'url': 'https://www.reuters.com/breakingviews/ukraines-spare-energy-can-help-itself-europe-2022-05-20/',
#    'urlToImage': 'https://www.reuters.com/resizer/Omt_BvssiTaJW1aDM9aaaoyExaQ=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/XQHCSPTPXJP3THRISQV4BYFVQE.jpg',
#    'publishedAt': '2022-05-20T09:47:00Z',
#    'content': 'MILAN, May 20 (Reuters Breakingviews) - Ukraine has an in-built weapon against the destruction wrought by conflict. With 55 gigawatts (GW) of installed power capacity, the war-torn nation can produce… [+3534 chars]'},
#   {'source': {'id': 'cnn', 'name': 'CNN'},
#    'author': 'Kristen Rogers',
#    'title': 'There are moms worse than you -- in the animal kingdom',
#    'description': 'Comedy writer Glenn Boozan\'s new book "There Are Moms Worse Than You" details horrific parenting practices of animal moms -- aiming to help human moms feel better and know that their best is good enough.',
#    'url': 'https://www.cnn.com/2022/05/08/world/moms-than-you-book-wellness-scn/index.html',
#    'urlToImage': 'https://media.cnn.com/api/v1/images/stellar/prod/220505134218-04-worse-moms.jpg?c=16x9&q=w_800,c_fill',
#    'publishedAt': '2022-05-08T12:25:23Z',
#    'content': 'If youre a mother, you have probably experienced the mental what if game on repeat since you found out you were becoming a parent. \r\nWhat if my kid never learns to read? What if they like another par… [+4245 chars]'},
#   {'source': {'id': 'cnn', 'name': 'CNN'},
#    'author': 'Katie Hunt, CNN',
#    'title': 'Tiny tooth fills in gaps in the human family tree',
#    'description': "This week, unlock a new clue in human evolution's biggest mystery, meet the smart creatures harnessing a 'medicine chest' under the sea, learn how your hair could help oil spills, and more.",
#    'url': 'https://www.cnn.com/2022/05/21/world/laos-tooth-science-newsletter-wt-scn/index.html',
#    'urlToImage': 'https://cdn.cnn.com/cnnnext/dam/assets/220517104224-02-tooth-laos-denisovans-super-tease.jpg',
#    'publishedAt': '2022-05-21T15:04:25Z',
# ...
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': "France's Macron offers to help lift Russia embargo on Ukraine food exports - Reuters",
#    'description': "French President Emmanuel Macron told Russian President Vladimir Putin in a phone call on Tuesday that he is willing to work with international organisations to help lift the Russian embargo on Ukrainian food exports via the Black Sea, Macron's office said.",
#    'url': 'https://www.reuters.com/world/europe/frances-macron-offers-help-lift-russia-embargo-ukraine-food-exports-2022-05-03/',
#    'urlToImage': 'https://www.reuters.com/resizer/nIXzC748WS4s5IeAgCTWBw9jYNw=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/NHQFVDF3GBJ4XP5GW64MBOOD6E.jpg',
#    'publishedAt': '2022-05-03T15:57:00Z',
#    'content': 'PARIS, May 3 (Reuters) - French President Emmanuel Macron told Russian President Vladimir Putin in a phone call on Tuesday that he is willing to work with international organisations to help lift the… [+625 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'UK spending to help squeezed voters would risk spiralling inflation -minister - Reuters.com',
#    'description': 'Britain risks an inflationary spiral if the government bows to pressure to help voters hit by rising food and energy bills, environment minister George Eustice said on Wednesday before what he predicted would be difficult local elections this week.',
#    'url': 'https://www.reuters.com/world/uk/uk-spending-help-squeezed-voters-would-risk-spiralling-inflation-minister-2022-05-04/',
#    'urlToImage': 'https://www.reuters.com/resizer/WFY9SJge9_EwkU8Aq6kH7gaXWIA=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/WHCISDIYCVKJXDO6LMSIQR7TV4.jpg',
#    'publishedAt': '2022-05-04T08:58:00Z',
#    'content': 'LONDON, May 4 (Reuters) - Britain risks an inflationary spiral if the government bows to pressure to help voters hit by rising food and energy bills, environment minister George Eustice said on Wedne… [+2424 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'U.S. senators introduce bill to help FTC return money to scam victims - Reuters.com',
#    'description': "Four Democratic senators, including Senators Maria Cantwell and Amy Klobuchar, introduced a bill that would allow the U.S. Federal Trade Commission return money to scam victims, Cantwell's office said in a statement Wednesday.",
#    'url': 'https://www.reuters.com/legal/litigation/us-senators-introduce-bill-help-ftc-return-money-scam-victims-2022-05-05/',
#    'urlToImage': 'https://www.reuters.com/resizer/4j6202bI_SuoQLaqNsXR99-zYFk=/728x381/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/KXBSD7V6XBOBZJWU2HW6LWIDTI.jpg',
#    'publishedAt': '2022-05-05T01:28:00Z',
#    'content': 'WASHINGTON, May 4 (Reuters) - Four Democratic senators, including Senators Maria Cantwell and Amy Klobuchar, introduced a bill that would allow the U.S. Federal Trade Commission return money to scam … [+1813 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'UK will "do things" to help ease cost-of-living crisis, PM Johnson says - Reuters UK',
#    'description': 'British Prime Minister Boris Johnson said on Thursday that his government would "do things" in the short term to help Britons with a cost-of-living crisis, without going into any details on what the measures could be.',
#    'url': 'https://www.reuters.com/world/uk/uk-will-do-things-help-ease-cost-of-living-crisis-pm-johnson-says-2022-05-12/',
#    'urlToImage': 'https://www.reuters.com/resizer/IVL_MZwrOcsetJn4Q-H4dex8oCw=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/SIZXAOUIPRI7DPUDLT37KC6ODQ.jpg',
#    'publishedAt': '2022-05-12T14:21:00Z',
#    'content': 'LONDON, May 12 (Reuters) - British Prime Minister Boris Johnson said on Thursday that his government would "do things" in the short term to help Britons with a cost-of-living crisis, without going in… [+461 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': "'Save Azovstal!' Relatives of Ukrainian fighters in steel plant plead for help - Reuters.com",
#    'description': 'Relatives and supporters of the Ukrainian fighters holed up in the Azovstal steel plant demonstrated in Kyiv on Thursday, pleading for them to be rescued.',
#    'url': 'https://www.reuters.com/world/europe/save-azovstal-relatives-ukrainian-fighters-steel-plant-plead-help-2022-05-12/',
#    'urlToImage': 'https://www.reuters.com/resizer/UdDoD0hSdBx0q8XsURTWx43pLPY=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/AYFRKZRUZNLMVCCG4N763273AM.jpg',
#    'publishedAt': '2022-05-12T21:45:00Z',
#    'content': 'May 12 (Reuters) - Relatives and supporters of the Ukrainian fighters holed up in the Azovstal steel plant demonstrated in Kyiv on Thursday, pleading for them to be rescued.\r\nRussian forces have been… [+1613 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'EBRD to help boost Middle East/North Africa food storage - Reuters',
#    'description': 'The European Bank for Reconstruction and Development (EBRD) is in talks with Morocco, Tunisia and Egypt to boost their food storage capacities and diversify their food suppliers, a senior bank official said on Tuesday.',
#    'url': 'https://www.reuters.com/world/middle-east/ebrd-help-boost-middle-eastnorth-africa-food-storage-2022-05-10/',
#    'urlToImage': 'https://www.reuters.com/pf/resources/images/reuters/reuters-default.png?d=94',
#    'publishedAt': '2022-05-10T20:16:00Z',
#    'content': 'MARRAKECH, Morocco, May 10 (Reuters) - The European Bank for Reconstruction and Development (EBRD) is in talks with Morocco, Tunisia and Egypt to boost their food storage capacities and diversify the… [+1629 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'UK will "of course" offer more cost-of-living help, Johnson says - Reuters UK',
#    'description': 'British Prime Minister Boris Johnson said on Wednesday his government would "of course" provide more support for people struggling to cope with surging inflation.',
#    'url': 'https://www.reuters.com/world/uk/uk-will-course-offer-more-cost-of-living-help-johnson-says-2022-05-11/',
#    'urlToImage': 'https://www.reuters.com/resizer/7bT4xM8th9P1HIeqDEpfOMPpJoQ=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/3PJWH2J6ZVIWVJDNKDBFV6VIPE.jpg',
#    'publishedAt': '2022-05-11T17:39:00Z',
#    'content': 'HELSINKI, May 11 (Reuters) - British Prime Minister Boris Johnson said on Wednesday his government would "of course" provide more support for people struggling to cope with surging inflation.\r\nJohnso… [+1182 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'U.S. Senate panel advances bill to help FTC fight deception, fraud - Reuters.com',
#    'description': 'U.S. lawmakers on Wednesday sent to the Senate floor a Democratic-backed bill that would allow the Federal Trade Commission to force deceptive companies to return money to victims.',
#    'url': 'https://www.reuters.com/world/us/us-senate-panel-advances-bill-help-ftc-fight-deception-fraud-2022-05-11/',
#    'urlToImage': 'https://www.reuters.com/resizer/nqpfoevRZVn4UTv_JPGJzTMNKPw=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/2DKBVXMAMJK6REB3CCO3IHFAYQ.jpg',
#    'publishedAt': '2022-05-11T15:55:00Z',
#    'content': 'WASHINGTON, May 11 (Reuters) - U.S. lawmakers on Wednesday sent to the Senate floor a Democratic-backed bill that would allow the Federal Trade Commission to force deceptive companies to return money… [+2014 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Editorial',
#    'title': 'Ghana says it will solve debt crisis without IMF help - Reuters.com',
#    'description': 'Ghana is committed to managing its debt without assistance from the International Monetary Fund (IMF), Finance Minister Ken Ofori-Atta said, expressing his confidence that government measures were moving the country in the right direction. Louisa Naks reports.',
#    'url': 'https://www.reuters.com/video/watch/idOV759912052022RP1',
#    'urlToImage': 'https://static.reuters.com/resources/r/?d=20220512&i=OV759912052022RP1&r=OV759912052022RP1&t=2',
#    'publishedAt': '2022-05-12T16:34:16Z',
#    'content': 'Posted \r\nGhana is committed to managing its debt without assistance from the International Monetary Fund (IMF), Finance Minister Ken Ofori-Atta said, expressing his confidence that government measure… [+69 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': "Microsoft to help cover U.S. employees' travel costs for abortion - Reuters",
#    'description': 'Microsoft Corp <a href="https://www.reuters.com/companies/MSFT.O" target="_blank">(MSFT.O)</a> said on Monday that it would extend its abortion and gender affirming care services for employees in the United States to include travel expense assistance.',
#    'url': 'https://www.reuters.com/world/us/microsoft-help-cover-us-employees-travel-costs-abortion-2022-05-10/',
#    'urlToImage': 'https://www.reuters.com/resizer/W9an87IhY1vxfXptvB5tVNYaVnE=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/6NTFSOSGNNJRLC7H7MPI7D5CPI.jpg',
#    'publishedAt': '2022-05-10T00:50:00Z',
#    'content': 'May 9 (Reuters) - Microsoft Corp (MSFT.O) said on Monday that it would extend its abortion and gender affirming care services for employees in the United States to include travel expense assistance.\r… [+1433 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Mexico to suspend import duties on foods to help curb inflation - Reuters.com',
#    'description': 'Mexico will waive import duties for one year on a range of household staples, most of them foodstuffs, in a bid to curb inflation, the government said in its official gazette on Monday.',
#    'url': 'https://www.reuters.com/markets/commodities/mexico-suspend-import-duties-foods-help-curb-inflation-2022-05-16/',
#    'urlToImage': 'https://www.reuters.com/resizer/Iu2d3niEDwPLCpyE5xXaB7jixIU=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/Z4JHTY3Q6FL63C2HWOWMRTO4TM.jpg',
#    'publishedAt': '2022-05-16T12:38:00Z',
#    'content': 'MEXICO CITY, May 16 (Reuters) - Mexico will waive import duties for one year on a range of household staples, most of them foodstuffs, in a bid to curb inflation, the government said in its official … [+976 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'N.Y. nonprofit may help debtors without breaking legal practice rules, judge says - Reuters.com',
#    'description': 'Nonprofit Upsolve Inc has opened up its legal advice program to non-lawyer volunteers after a Manhattan federal judge ruled in favor of its First Amendment argument in a lawsuit against the state attorney general.',
#    'url': 'https://www.reuters.com/legal/government/ny-nonprofit-may-help-debtors-without-breaking-legal-practice-rules-judge-says-2022-05-25/',
#    'urlToImage': 'https://www.reuters.com/resizer/5rf341X2dKPcA-v-2eOukZPB8V8=/728x381/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/KCIPELUQSNJTVG6LAXJO7ICI6E.jpg',
#    'publishedAt': '2022-05-25T16:18:00Z',
#    'content': '<ul><li>\r\nSummary</li><li>\r\nLaw firms</li><li>\r\nRelated documents</li></ul>\r\n(Reuters) - Nonprofit Upsolve Inc has opened up its legal advice program to non-lawyer volunteers after a Manhattan federa… [+2971 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Nordic neighbours vow to help Finland and Sweden in case of attack - Reuters.com',
#    'description': 'Norway, Denmark and Iceland in a joint statement on Monday said they stand ready to support NATO applicants Finland and Sweden in case the two Nordic nations were to come under attack.',
#    'url': 'https://www.reuters.com/world/europe/nordic-neighbours-vow-help-finland-sweden-case-attack-2022-05-16/',
#    'urlToImage': 'https://www.reuters.com/resizer/hNYIVd3F-O7h_gh7fbEq_GPsnJ0=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/VRC6WX2S3RN7LGMPSILG2CQJZE.jpg',
#    'publishedAt': '2022-05-16T15:02:00Z',
#    'content': 'OSLO/COPENHAGEN, May 16 (Reuters) - Norway, Denmark and Iceland in a joint statement on Monday said they stand ready to support NATO applicants Finland and Sweden in case the two Nordic nations were … [+458 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'Danish anti-ship missiles expected to help Ukraine control its Black Sea coast - Reuters',
#    'description': "Copenhagen's pledge of Harpoon anti-ship missiles and a launcher to Ukraine, announced by the United States on Monday, is the first sign since the Russian invasion in February that Kyiv will receive U.S.-made weapons that significantly extend its striking ran…",
#    'url': 'https://www.reuters.com/world/danish-anti-ship-missiles-expected-help-ukraine-control-its-black-sea-coast-2022-05-23/',
#    'urlToImage': 'https://www.reuters.com/resizer/wGVtfimPum07v1puAbAKr6oDBW0=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/KEBRVCXI3RJUTDAZA2VDTBKFEM.jpg',
#    'publishedAt': '2022-05-23T21:05:00Z',
#    'content': "WASHINGTON, May 23 (Reuters) - Copenhagen's pledge of Harpoon anti-ship missiles and a launcher to Ukraine, announced by the United States on Monday, is the first sign since the Russian invasion in F… [+2367 chars]"},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'G7 mulling Russian asset seizures to help rebuild Ukraine - German FinMin - Reuters.com',
#    'description': 'Seizing Russian state assets to help finance the rebuilding of war-torn Ukraine remains a possibility, German Finance Minister Christian Lindner said on Friday, but he added that no decision on the matter was taken at a meeting with his G7 counterparts.',
#    'url': 'https://www.reuters.com/world/europe/g7-mulling-russian-asset-seizures-help-rebuild-ukraine-german-finmin-2022-05-20/',
#    'urlToImage': 'https://www.reuters.com/resizer/qDtqnjl2HjchdIQzo2tNlbiYQlQ=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/2UXS4RUH25IPTOZQJQPB4TBQRA.jpg',
#    'publishedAt': '2022-05-20T13:03:00Z',
#    'content': 'BERLIN, May 20 (Reuters) - Seizing Russian state assets to help finance the rebuilding of war-torn Ukraine remains a possibility, German Finance Minister Christian Lindner said on Friday, but he adde… [+529 chars]'},
#   {'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': None,
#    'title': 'White House looks to help smaller cities get infrastructure boost - Reuters',
#    'description': 'The White House and philanthropic agencies are working to make it easier for smaller cities and counties to apply for funding under a $1 trillion infrastructure law that aims to rebuild U.S. roads, bridges, airports and expand broadband access.',
#    'url': 'https://www.reuters.com/world/us/white-house-looks-help-smaller-cities-get-infrastructure-boost-2022-05-18/',
#    'urlToImage': 'https://www.reuters.com/resizer/qYoLueKY5lQ9m4hwvWQUczqYnwc=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/OF47KASZIBNO3DQ25FGB2TUG6M.jpg',
#    'publishedAt': '2022-05-18T16:07:00Z',
#    'content': 'WASHINGTON, May 18 (Reuters) - The White House and philanthropic agencies are working to make it easier for smaller cities and counties to apply for funding under a $1 trillion infrastructure law tha… [+2088 chars]'}]}

# %%
# Create the sentiment scores DataFrame
btc_sentiments = []

for article in btc_headlines["articles"]:
    try:
        Date = article["publishedAt"]
        text = article["content"]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        btc_sentiments.append({
            "Date": Date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    
btc_df = pd.DataFrame(btc_sentiments)   
btc_df["Date"] = pd.to_datetime(btc_df["Date"])
btc_df = btc_df.set_index("Date")
btc_df = btc_df.sort_index()
btc_df
# Out:
#                            compound  positive  negative  neutral
# Date
# 2022-04-29 12:27:30+00:00    0.0000     0.000     0.000    1.000
# 2022-04-29 19:45:40+00:00   -0.0015     0.071     0.071    0.858
# 2022-04-29 23:12:32+00:00   -0.8689     0.000     0.247    0.753
# 2022-04-29 23:24:28+00:00    0.0000     0.000     0.000    1.000
# 2022-04-30 06:00:49+00:00   -0.8570     0.000     0.217    0.783
# ...                             ...       ...       ...      ...
# 2022-05-30 16:48:00+00:00    0.8225     0.268     0.000    0.732
# 2022-05-30 21:26:58+00:00   -0.6369     0.108     0.208    0.684
# 2022-05-30 23:05:16+00:00    0.2023     0.055     0.000    0.945
# 2022-05-31 04:38:00+00:00    0.2500     0.088     0.000    0.912
# 2022-05-31 07:00:12+00:00   -0.3818     0.066     0.109    0.824
#
# [100 rows x 4 columns]

# %%
btc_df.index = btc_df.index.round('15min')
btc_df.index = btc_df.index.tz_localize(None)
btc_df
# Out:
#                      compound  positive  negative  neutral
# Date
# 2022-04-29 12:30:00    0.0000     0.000     0.000    1.000
# 2022-04-29 19:45:00   -0.0015     0.071     0.071    0.858
# 2022-04-29 23:15:00   -0.8689     0.000     0.247    0.753
# 2022-04-29 23:30:00    0.0000     0.000     0.000    1.000
# 2022-04-30 06:00:00   -0.8570     0.000     0.217    0.783
# ...                       ...       ...       ...      ...
# 2022-05-30 16:45:00    0.8225     0.268     0.000    0.732
# 2022-05-30 21:30:00   -0.6369     0.108     0.208    0.684
# 2022-05-30 23:00:00    0.2023     0.055     0.000    0.945
# 2022-05-31 04:45:00    0.2500     0.088     0.000    0.912
# 2022-05-31 07:00:00   -0.3818     0.066     0.109    0.824
#
# [100 rows x 4 columns]

# %%
# Creacting a binary response for the tsla stock
btc_df['comp_score'] = btc_df['compound'].apply(lambda c: '1' if c >=0 else '0')

btc_df.tail()
# Out:
#                      compound  positive  negative  neutral comp_score
# Date
# 2022-05-30 16:45:00    0.8225     0.268     0.000    0.732          1
# 2022-05-30 21:30:00   -0.6369     0.108     0.208    0.684          0
# 2022-05-30 23:00:00    0.2023     0.055     0.000    0.945          1
# 2022-05-31 04:45:00    0.2500     0.088     0.000    0.912          1
# 2022-05-31 07:00:00   -0.3818     0.066     0.109    0.824          0

# %%
btc_trading_data = pd.read_csv(
    Path("Sentiment_data/btc_data_5m.csv"), 
    index_col="Date", 
    infer_datetime_format=True, 
    parse_dates=True
)

# Review the DataFrame
btc_trading_data.tail()
# Out:
#                          Open      High       Low     Close  Volume_base  \
# Date
# 2022-04-19 08:15:00  55155.87  55200.31  55121.01  55121.01      3.11221
# 2022-04-19 08:30:00  55121.01  55265.87  55110.97  55255.67      1.75836
# 2022-04-19 08:45:00  55254.41  55324.55  55221.07  55221.07      2.12392
# 2022-04-19 09:00:00  55208.59  55225.92  55150.33  55178.90      3.01601
# 2022-04-19 09:15:00  55165.19  55199.89  55165.19  55195.68      0.77454
#
#                       Volume_quote
# Date
# 2022-04-19 08:15:00  171690.325162
# 2022-04-19 08:30:00   97031.437113
# 2022-04-19 08:45:00  117354.636360
# 2022-04-19 09:00:00  166483.479149
# 2022-04-19 09:15:00   42743.375230

# %%
result_df = pd.merge(btc_trading_data, btc_df, left_index=True, right_index=True)
result_df
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Volume_base, Volume_quote, compound, positive, negative, neutral, comp_score]
# Index: []

# %%
#save as a df
result_df.to_csv("Sentiment_data/lithium_sentiment.csv",index=True)
